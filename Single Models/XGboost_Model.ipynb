# %%
# Demonstration data used in this excercise is already preprocessed and split into
# training, validation, and test sets

# Use wget to download the data stored in csv format.
import itertools

# Define what files to download; download all of the preprocessed data
# Note that the data are already split into Train, Validation, and Test sets.
# The predictor data are denoted with 'X', the target by 'y'
data_download = {}
data_download["window_size"] = [5, 15]
data_download["data_type"] = ["train", "valid", "test"]
data_download["predictor_or_target"] = ["X", "y"]

# Prepare the combinations of the window sizes and the data types
keys, values = zip(*data_download.items())
data_download_combinations = [dict(zip(keys, v)) for v in itertools.product(*values)]
display('The kind of data to be downloaded:', data_download_combinations)

print("Downloading started...")
for data_download_param in data_download_combinations:
  file_to_download = "https://frankfurt-school-dataset.s3.eu-central-1.amazonaws.com/Sept2021/window_size_{0}_time_encoding_True/{1}_{2}_window_size_{0}_time_encoding_True.csv"\
                     .format(data_download_param["window_size"], data_download_param["predictor_or_target"], data_download_param["data_type"])

  # the actual downloading
  # !wget "$file_to_download"

print("Downloading has finished")
# Out:
# 'The kind of data to be downloaded:'
# [{'data_type': 'train', 'predictor_or_target': 'X', 'window_size': 5},
#  {'data_type': 'train', 'predictor_or_target': 'y', 'window_size': 5},
#  {'data_type': 'valid', 'predictor_or_target': 'X', 'window_size': 5},
#  {'data_type': 'valid', 'predictor_or_target': 'y', 'window_size': 5},
#  {'data_type': 'test', 'predictor_or_target': 'X', 'window_size': 5},
#  {'data_type': 'test', 'predictor_or_target': 'y', 'window_size': 5},
#  {'data_type': 'train', 'predictor_or_target': 'X', 'window_size': 15},
#  {'data_type': 'train', 'predictor_or_target': 'y', 'window_size': 15},
#  {'data_type': 'valid', 'predictor_or_target': 'X', 'window_size': 15},
#  {'data_type': 'valid', 'predictor_or_target': 'y', 'window_size': 15},
#  {'data_type': 'test', 'predictor_or_target': 'X', 'window_size': 15},
#  {'data_type': 'test', 'predictor_or_target': 'y', 'window_size': 15}]
# Downloading started...
# --2021-11-10 15:23:11--  https://frankfurt-school-dataset.s3.eu-central-1.amazonaws.com/Sept2021/window_size_5_time_encoding_True/X_train_window_size_5_time_encoding_True.csv
# Resolving frankfurt-school-dataset.s3.eu-central-1.amazonaws.com (frankfurt-school-dataset.s3.eu-central-1.amazonaws.com)... 52.219.169.30
# Connecting to frankfurt-school-dataset.s3.eu-central-1.amazonaws.com (frankfurt-school-dataset.s3.eu-central-1.amazonaws.com)|52.219.169.30|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 53997719 (51M) [text/csv]
# Saving to: ‘X_train_window_size_5_time_encoding_True.csv’
#
# X_train_window_size 100%[===================>]  51.50M  18.0MB/s    in 2.9s
#
# 2021-11-10 15:23:14 (18.0 MB/s) - ‘X_train_window_size_5_time_encoding_True.csv’ saved [53997719/53997719]
#
# --2021-11-10 15:23:14--  https://frankfurt-school-dataset.s3.eu-central-1.amazonaws.com/Sept2021/window_size_5_time_encoding_True/y_train_window_size_5_time_encoding_True.csv
# Resolving frankfurt-school-dataset.s3.eu-central-1.amazonaws.com (frankfurt-school-dataset.s3.eu-central-1.amazonaws.com)... 52.219.169.30
# Connecting to frankfurt-school-dataset.s3.eu-central-1.amazonaws.com (frankfurt-school-dataset.s3.eu-central-1.amazonaws.com)|52.219.169.30|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1505402 (1.4M) [text/csv]
# Saving to: ‘y_train_window_size_5_time_encoding_True.csv’
#
# y_train_window_size 100%[===================>]   1.44M  2.18MB/s    in 0.7s
#
# 2021-11-10 15:23:15 (2.18 MB/s) - ‘y_train_window_size_5_time_encoding_True.csv’ saved [1505402/1505402]
#
# --2021-11-10 15:23:15--  https://frankfurt-school-dataset.s3.eu-central-1.amazonaws.com/Sept2021/window_size_5_time_encoding_True/X_valid_window_size_5_time_encoding_True.csv
# Resolving frankfurt-school-dataset.s3.eu-central-1.amazonaws.com (frankfurt-school-dataset.s3.eu-central-1.amazonaws.com)... 52.219.169.30
# Connecting to frankfurt-school-dataset.s3.eu-central-1.amazonaws.com (frankfurt-school-dataset.s3.eu-central-1.amazonaws.com)|52.219.169.30|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2931637 (2.8M) [text/csv]
# Saving to: ‘X_valid_window_size_5_time_encoding_True.csv’
#
# X_valid_window_size 100%[===================>]   2.79M  3.56MB/s    in 0.8s
#
# 2021-11-10 15:23:17 (3.56 MB/s) - ‘X_valid_window_size_5_time_encoding_True.csv’ saved [2931637/2931637]
#
# --2021-11-10 15:23:17--  https://frankfurt-school-dataset.s3.eu-central-1.amazonaws.com/Sept2021/window_size_5_time_encoding_True/y_valid_window_size_5_time_encoding_True.csv
# Resolving frankfurt-school-dataset.s3.eu-central-1.amazonaws.com (frankfurt-school-dataset.s3.eu-central-1.amazonaws.com)... 52.219.47.241
# Connecting to frankfurt-school-dataset.s3.eu-central-1.amazonaws.com (frankfurt-school-dataset.s3.eu-central-1.amazonaws.com)|52.219.47.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 82567 (81K) [text/csv]
# Saving to: ‘y_valid_window_size_5_time_encoding_True.csv’
#
# y_valid_window_size 100%[===================>]  80.63K   362KB/s    in 0.2s
#
# 2021-11-10 15:23:18 (362 KB/s) - ‘y_valid_window_size_5_time_encoding_True.csv’ saved [82567/82567]
#
# --2021-11-10 15:23:18--  https://frankfurt-school-dataset.s3.eu-central-1.amazonaws.com/Sept2021/window_size_5_time_encoding_True/X_test_window_size_5_time_encoding_True.csv
# Resolving frankfurt-school-dataset.s3.eu-central-1.amazonaws.com (frankfurt-school-dataset.s3.eu-central-1.amazonaws.com)... 52.219.47.241
# Connecting to frankfurt-school-dataset.s3.eu-central-1.amazonaws.com (frankfurt-school-dataset.s3.eu-central-1.amazonaws.com)|52.219.47.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6479846 (6.2M) [text/csv]
# Saving to: ‘X_test_window_size_5_time_encoding_True.csv’
#
# X_test_window_size_ 100%[===================>]   6.18M  6.85MB/s    in 0.9s
#
# 2021-11-10 15:23:19 (6.85 MB/s) - ‘X_test_window_size_5_time_encoding_True.csv’ saved [6479846/6479846]
#
# --2021-11-10 15:23:19--  https://frankfurt-school-dataset.s3.eu-central-1.amazonaws.com/Sept2021/window_size_5_time_encoding_True/y_test_window_size_5_time_encoding_True.csv
# Resolving frankfurt-school-dataset.s3.eu-central-1.amazonaws.com (frankfurt-school-dataset.s3.eu-central-1.amazonaws.com)... 52.219.47.241
# Connecting to frankfurt-school-dataset.s3.eu-central-1.amazonaws.com (frankfurt-school-dataset.s3.eu-central-1.amazonaws.com)|52.219.47.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 181827 (178K) [text/csv]
# Saving to: ‘y_test_window_size_5_time_encoding_True.csv’
#
# y_test_window_size_ 100%[===================>] 177.57K   531KB/s    in 0.3s
#
# 2021-11-10 15:23:20 (531 KB/s) - ‘y_test_window_size_5_time_encoding_True.csv’ saved [181827/181827]
#
# --2021-11-10 15:23:20--  https://frankfurt-school-dataset.s3.eu-central-1.amazonaws.com/Sept2021/window_size_15_time_encoding_True/X_train_window_size_15_time_encoding_True.csv
# Resolving frankfurt-school-dataset.s3.eu-central-1.amazonaws.com (frankfurt-school-dataset.s3.eu-central-1.amazonaws.com)... 52.219.47.241
# Connecting to frankfurt-school-dataset.s3.eu-central-1.amazonaws.com (frankfurt-school-dataset.s3.eu-central-1.amazonaws.com)|52.219.47.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 41978632 (40M) [text/csv]
# Saving to: ‘X_train_window_size_15_time_encoding_True.csv’
#
# X_train_window_size 100%[===================>]  40.03M  17.0MB/s    in 2.4s
#
# 2021-11-10 15:23:23 (17.0 MB/s) - ‘X_train_window_size_15_time_encoding_True.csv’ saved [41978632/41978632]
#
# --2021-11-10 15:23:23--  https://frankfurt-school-dataset.s3.eu-central-1.amazonaws.com/Sept2021/window_size_15_time_encoding_True/y_train_window_size_15_time_encoding_True.csv
# Resolving frankfurt-school-dataset.s3.eu-central-1.amazonaws.com (frankfurt-school-dataset.s3.eu-central-1.amazonaws.com)... 52.219.47.160
# Connecting to frankfurt-school-dataset.s3.eu-central-1.amazonaws.com (frankfurt-school-dataset.s3.eu-central-1.amazonaws.com)|52.219.47.160|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 531355 (519K) [text/csv]
# Saving to: ‘y_train_window_size_15_time_encoding_True.csv’
#
# y_train_window_size 100%[===================>] 518.90K   956KB/s    in 0.5s
#
# 2021-11-10 15:23:24 (956 KB/s) - ‘y_train_window_size_15_time_encoding_True.csv’ saved [531355/531355]
#
# --2021-11-10 15:23:24--  https://frankfurt-school-dataset.s3.eu-central-1.amazonaws.com/Sept2021/window_size_15_time_encoding_True/X_valid_window_size_15_time_encoding_True.csv
# Resolving frankfurt-school-dataset.s3.eu-central-1.amazonaws.com (frankfurt-school-dataset.s3.eu-central-1.amazonaws.com)... 52.219.47.160
# Connecting to frankfurt-school-dataset.s3.eu-central-1.amazonaws.com (frankfurt-school-dataset.s3.eu-central-1.amazonaws.com)|52.219.47.160|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2262426 (2.2M) [text/csv]
# Saving to: ‘X_valid_window_size_15_time_encoding_True.csv’
#
# X_valid_window_size 100%[===================>]   2.16M  2.82MB/s    in 0.8s
#
# 2021-11-10 15:23:26 (2.82 MB/s) - ‘X_valid_window_size_15_time_encoding_True.csv’ saved [2262426/2262426]
#
# --2021-11-10 15:23:26--  https://frankfurt-school-dataset.s3.eu-central-1.amazonaws.com/Sept2021/window_size_15_time_encoding_True/y_valid_window_size_15_time_encoding_True.csv
# Resolving frankfurt-school-dataset.s3.eu-central-1.amazonaws.com (frankfurt-school-dataset.s3.eu-central-1.amazonaws.com)... 52.219.47.160
# Connecting to frankfurt-school-dataset.s3.eu-central-1.amazonaws.com (frankfurt-school-dataset.s3.eu-central-1.amazonaws.com)|52.219.47.160|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27675 (27K) [text/csv]
# Saving to: ‘y_valid_window_size_15_time_encoding_True.csv’
#
# y_valid_window_size 100%[===================>]  27.03K  --.-KB/s    in 0.1s
#
# 2021-11-10 15:23:26 (239 KB/s) - ‘y_valid_window_size_15_time_encoding_True.csv’ saved [27675/27675]
#
# --2021-11-10 15:23:26--  https://frankfurt-school-dataset.s3.eu-central-1.amazonaws.com/Sept2021/window_size_15_time_encoding_True/X_test_window_size_15_time_encoding_True.csv
# Resolving frankfurt-school-dataset.s3.eu-central-1.amazonaws.com (frankfurt-school-dataset.s3.eu-central-1.amazonaws.com)... 52.219.47.160
# Connecting to frankfurt-school-dataset.s3.eu-central-1.amazonaws.com (frankfurt-school-dataset.s3.eu-central-1.amazonaws.com)|52.219.47.160|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5152033 (4.9M) [text/csv]
# Saving to: ‘X_test_window_size_15_time_encoding_True.csv’
#
# X_test_window_size_ 100%[===================>]   4.91M  5.56MB/s    in 0.9s
#
# 2021-11-10 15:23:28 (5.56 MB/s) - ‘X_test_window_size_15_time_encoding_True.csv’ saved [5152033/5152033]
#
# --2021-11-10 15:23:28--  https://frankfurt-school-dataset.s3.eu-central-1.amazonaws.com/Sept2021/window_size_15_time_encoding_True/y_test_window_size_15_time_encoding_True.csv
# Resolving frankfurt-school-dataset.s3.eu-central-1.amazonaws.com (frankfurt-school-dataset.s3.eu-central-1.amazonaws.com)... 52.219.47.168
# Connecting to frankfurt-school-dataset.s3.eu-central-1.amazonaws.com (frankfurt-school-dataset.s3.eu-central-1.amazonaws.com)|52.219.47.168|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 61541 (60K) [text/csv]
# Saving to: ‘y_test_window_size_15_time_encoding_True.csv’
#
# y_test_window_size_ 100%[===================>]  60.10K   278KB/s    in 0.2s
#
# 2021-11-10 15:23:29 (278 KB/s) - ‘y_test_window_size_15_time_encoding_True.csv’ saved [61541/61541]
#
# Downloading has finished

# %%
import pandas as pd 
import numpy as np

# %%
# !pip install seglearn
# Out:
# Collecting seglearn
#   Downloading seglearn-1.2.3-py3-none-any.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 4.9 MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from seglearn) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.7/dist-packages (from seglearn) (0.22.2.post1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from seglearn) (1.19.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seglearn) (1.1.0)
# Installing collected packages: seglearn
# Successfully installed seglearn-1.2.3

# %%
def load_data(num):

    X_train = pd.read_csv("X_train_window_size_{}_time_encoding_True.csv".format(num))
    y_train = pd.read_csv("y_train_window_size_{}_time_encoding_True.csv".format(num))

    X_valid = pd.read_csv("X_valid_window_size_{}_time_encoding_True.csv".format(num))
    y_valid = pd.read_csv("y_valid_window_size_{}_time_encoding_True.csv".format(num))

    return X_train, y_train, X_valid, y_valid

# %%
def evaluate_model(model,X_valid, y_valid):
    from math import sqrt
    from sklearn.metrics import mean_squared_error, mean_absolute_error

    predictions = model.predict(X_valid)
    mse = mean_squared_error(y_valid, predictions)
    mae = mean_absolute_error(y_valid, predictions)
    # normalized_rms = normalizers["y"].inverse_transform(np.array([rms]).reshape(1, -1))[0][0]
    # print("Root mean squared error on valid inverse transformed from normalization:",normalized_rms)
    return mse, mae

# %%
def display_history(history,name ="None"):
    import matplotlib.pyplot as plt
    """Summarize history for accuracy and loss.
    """
    fig, axs = plt.subplots(ncols=1,figsize=(10,6),sharey='row')
    title = "Loss_for_{}".format(name)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title(title)
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'valid'], loc='upper left')
    # plt.savefig(name)
    fig.savefig(title + '.png')
    plt.show()

# %%
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import TimeSeriesSplit
xgbreg = xgb.XGBRegressor()
param_grid = {'max_depth': [2,5,12], 
              'n_estimators': [10, 50, 100, 150],
              'learning_rate': [0.1, 0.01, 0.05]}
X_train, y_train, X_valid, y_valid = load_data(5)
y_train = y_train.values.reshape(y_train.shape[0],)
my_cv = TimeSeriesSplit(n_splits=2)
CV_xgbmodel = GridSearchCV(estimator=xgbreg, param_grid=param_grid, cv = my_cv, verbose = 2) #n_jobs = -1
CV_xgbmodel.fit(X_train, y_train)
#the first grid search for XG boost with varied max depths of [2,5,12], varied n estimators of [10,50,100,150] and learning rates of [0.1, 0.01,0.05]
# Out:
# Fitting 2 folds for each of 36 candidates, totalling 72 fits
# [CV] learning_rate=0.1, max_depth=2, n_estimators=10 .................
# [16:26:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] .. learning_rate=0.1, max_depth=2, n_estimators=10, total=   1.2s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=10 .................
# [16:26:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s remaining:    0.0s
# [CV] .. learning_rate=0.1, max_depth=2, n_estimators=10, total=   0.8s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=50 .................
# [16:26:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.1, max_depth=2, n_estimators=50, total=   1.4s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=50 .................
# [16:26:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.1, max_depth=2, n_estimators=50, total=   2.9s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=100 ................
# [16:26:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.1, max_depth=2, n_estimators=100, total=   2.6s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=100 ................
# [16:26:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.1, max_depth=2, n_estimators=100, total=   5.6s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=150 ................
# [16:26:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.1, max_depth=2, n_estimators=150, total=   3.9s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=150 ................
# [16:26:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.1, max_depth=2, n_estimators=150, total=   8.3s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=10 .................
# [16:26:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.1, max_depth=5, n_estimators=10, total=   0.7s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=10 .................
# [16:26:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.1, max_depth=5, n_estimators=10, total=   1.4s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=50 .................
# [16:26:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.1, max_depth=5, n_estimators=50, total=   3.0s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=50 .................
# [16:26:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.1, max_depth=5, n_estimators=50, total=   6.4s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=100 ................
# [16:26:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.1, max_depth=5, n_estimators=100, total=   6.1s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=100 ................
# [16:26:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.1, max_depth=5, n_estimators=100, total=  12.5s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=150 ................
# [16:27:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.1, max_depth=5, n_estimators=150, total=   9.1s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=150 ................
# [16:27:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.1, max_depth=5, n_estimators=150, total=  18.9s
# [CV] learning_rate=0.1, max_depth=12, n_estimators=10 ................
# [16:27:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.1, max_depth=12, n_estimators=10, total=   1.4s
# [CV] learning_rate=0.1, max_depth=12, n_estimators=10 ................
# [16:27:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.1, max_depth=12, n_estimators=10, total=   3.0s
# [CV] learning_rate=0.1, max_depth=12, n_estimators=50 ................
# [16:27:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.1, max_depth=12, n_estimators=50, total=   8.2s
# [CV] learning_rate=0.1, max_depth=12, n_estimators=50 ................
# [16:27:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.1, max_depth=12, n_estimators=50, total=  17.3s
# [CV] learning_rate=0.1, max_depth=12, n_estimators=100 ...............
# [16:28:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.1, max_depth=12, n_estimators=100, total=  20.1s
# [CV] learning_rate=0.1, max_depth=12, n_estimators=100 ...............
# [16:28:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.1, max_depth=12, n_estimators=100, total=  41.6s
# [CV] learning_rate=0.1, max_depth=12, n_estimators=150 ...............
# [16:29:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.1, max_depth=12, n_estimators=150, total=  32.2s
# [CV] learning_rate=0.1, max_depth=12, n_estimators=150 ...............
# [16:29:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.1, max_depth=12, n_estimators=150, total= 1.1min
# [CV] learning_rate=0.01, max_depth=2, n_estimators=10 ................
# [16:30:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.01, max_depth=2, n_estimators=10, total=   0.4s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=10 ................
# [16:30:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.01, max_depth=2, n_estimators=10, total=   0.8s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=50 ................
# [16:30:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.01, max_depth=2, n_estimators=50, total=   1.3s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=50 ................
# [16:30:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.01, max_depth=2, n_estimators=50, total=   2.9s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=100 ...............
# [16:30:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=100, total=   2.5s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=100 ...............
# [16:30:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=100, total=   5.5s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=150 ...............
# [16:31:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=150, total=   3.7s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=150 ...............
# [16:31:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=150, total=   8.1s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=10 ................
# [16:31:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.01, max_depth=5, n_estimators=10, total=   0.7s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=10 ................
# [16:31:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.01, max_depth=5, n_estimators=10, total=   1.4s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=50 ................
# [16:31:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.01, max_depth=5, n_estimators=50, total=   2.8s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=50 ................
# [16:31:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.01, max_depth=5, n_estimators=50, total=   6.0s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=100 ...............
# [16:31:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=100, total=   5.6s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=100 ...............
# [16:31:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=100, total=  11.8s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=150 ...............
# [16:31:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=150, total=   8.4s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=150 ...............
# [16:31:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=150, total=  17.3s
# [CV] learning_rate=0.01, max_depth=12, n_estimators=10 ...............
# [16:32:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.01, max_depth=12, n_estimators=10, total=   1.4s
# [CV] learning_rate=0.01, max_depth=12, n_estimators=10 ...............
# [16:32:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.01, max_depth=12, n_estimators=10, total=   3.1s
# [CV] learning_rate=0.01, max_depth=12, n_estimators=50 ...............
# [16:32:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.01, max_depth=12, n_estimators=50, total=   6.7s
# [CV] learning_rate=0.01, max_depth=12, n_estimators=50 ...............
# [16:32:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.01, max_depth=12, n_estimators=50, total=  14.3s
# [CV] learning_rate=0.01, max_depth=12, n_estimators=100 ..............
# [16:32:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.01, max_depth=12, n_estimators=100, total=  13.4s
# [CV] learning_rate=0.01, max_depth=12, n_estimators=100 ..............
# [16:32:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.01, max_depth=12, n_estimators=100, total=  28.7s
# [CV] learning_rate=0.01, max_depth=12, n_estimators=150 ..............
# [16:33:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.01, max_depth=12, n_estimators=150, total=  20.7s
# [CV] learning_rate=0.01, max_depth=12, n_estimators=150 ..............
# [16:33:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.01, max_depth=12, n_estimators=150, total=  42.9s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=10 ................
# [16:34:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.05, max_depth=2, n_estimators=10, total=   0.4s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=10 ................
# [16:34:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.05, max_depth=2, n_estimators=10, total=   0.8s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=50 ................
# [16:34:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.05, max_depth=2, n_estimators=50, total=   1.3s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=50 ................
# [16:34:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.05, max_depth=2, n_estimators=50, total=   2.8s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=100 ...............
# [16:34:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=100, total=   2.6s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=100 ...............
# [16:34:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=100, total=   5.6s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=150 ...............
# [16:34:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=150, total=   3.8s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=150 ...............
# [16:34:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=150, total=   8.4s
# [CV] learning_rate=0.05, max_depth=5, n_estimators=10 ................
# [16:34:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.05, max_depth=5, n_estimators=10, total=   0.7s
# [CV] learning_rate=0.05, max_depth=5, n_estimators=10 ................
# [16:34:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.05, max_depth=5, n_estimators=10, total=   1.4s
# [CV] learning_rate=0.05, max_depth=5, n_estimators=50 ................
# [16:34:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.05, max_depth=5, n_estimators=50, total=   2.9s
# [CV] learning_rate=0.05, max_depth=5, n_estimators=50 ................
# [16:34:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.05, max_depth=5, n_estimators=50, total=   6.1s
# [CV] learning_rate=0.05, max_depth=5, n_estimators=100 ...............
# [16:34:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.05, max_depth=5, n_estimators=100, total=   5.9s
# [CV] learning_rate=0.05, max_depth=5, n_estimators=100 ...............
# [16:35:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.05, max_depth=5, n_estimators=100, total=  12.2s
# [CV] learning_rate=0.05, max_depth=5, n_estimators=150 ...............
# [16:35:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.05, max_depth=5, n_estimators=150, total=   9.0s
# [CV] learning_rate=0.05, max_depth=5, n_estimators=150 ...............
# [16:35:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.05, max_depth=5, n_estimators=150, total=  19.1s
# [CV] learning_rate=0.05, max_depth=12, n_estimators=10 ...............
# [16:35:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.05, max_depth=12, n_estimators=10, total=   1.5s
# [CV] learning_rate=0.05, max_depth=12, n_estimators=10 ...............
# [16:35:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.05, max_depth=12, n_estimators=10, total=   3.1s
# [CV] learning_rate=0.05, max_depth=12, n_estimators=50 ...............
# [16:35:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.05, max_depth=12, n_estimators=50, total=   7.1s
# [CV] learning_rate=0.05, max_depth=12, n_estimators=50 ...............
# [16:35:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.05, max_depth=12, n_estimators=50, total=  14.8s
# [CV] learning_rate=0.05, max_depth=12, n_estimators=100 ..............
# [16:36:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.05, max_depth=12, n_estimators=100, total=  17.0s
# [CV] learning_rate=0.05, max_depth=12, n_estimators=100 ..............
# [16:36:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.05, max_depth=12, n_estimators=100, total=  36.2s
# [CV] learning_rate=0.05, max_depth=12, n_estimators=150 ..............
# [16:37:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.05, max_depth=12, n_estimators=150, total=  29.1s
# [CV] learning_rate=0.05, max_depth=12, n_estimators=150 ..............
# [16:37:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.05, max_depth=12, n_estimators=150, total=  59.3s
# [16:38:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Done  72 out of  72 | elapsed: 12.3min finished
# GridSearchCV(cv=TimeSeriesSplit(max_train_size=None, n_splits=2),
#              error_score=nan,
#              estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                     colsample_bylevel=1, colsample_bynode=1,
#                                     colsample_bytree=1, gamma=0,
#                                     importance_type='gain', learning_rate=0.1,
#                                     max_delta_step=0, max_depth=3,
#                                     min_child_weight=1, missing=None,
#                                     n_estimators=100, n_jobs=1, nthread=None,
#                                     objective='reg:linear', random_state=0,
#                                     reg_alpha=0, reg_lambda=1,
#                                     scale_pos_weight=1, seed=None, silent=None,
#                                     subsample=1, verbosity=1),
#              iid='deprecated', n_jobs=None,
#              param_grid={'learning_rate': [0.1, 0.01, 0.05],
#                          'max_depth': [2, 5, 12],
#                          'n_estimators': [10, 50, 100, 150]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=2)

# %%
print(CV_xgbmodel.best_score_, CV_xgbmodel.best_params_)

evaluate_model(CV_xgbmodel, X_valid, y_valid)
#best MAE window 5
# Out:
# -0.006784124257238178 {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 10}
# (26.07753730646325, 2.5847180467478985)

# %%
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import TimeSeriesSplit
xgbreg = xgb.XGBRegressor()
param_grid = {'max_depth': [2,5,12], 
              'n_estimators': [10, 50, 100, 150],
              'learning_rate': [0.1, 0.01, 0.05]}
X_train, y_train, X_valid, y_valid = load_data(15)
y_train = y_train.values.reshape(y_train.shape[0],)
my_cv = TimeSeriesSplit(n_splits=2)
CV_xgbmodel = GridSearchCV(estimator=xgbreg, param_grid=param_grid, cv = my_cv, verbose = 2) #n_jobs = -1
CV_xgbmodel.fit(X_train, y_train)
#the first grid search for XG boost window size 15 with varied max depths of [2,5,12], varied n estimators of [10,50,100,150] and learning rates of [0.1, 0.01,0.05]
# Out:
# Fitting 2 folds for each of 36 candidates, totalling 72 fits
# [CV] learning_rate=0.1, max_depth=2, n_estimators=10 .................
# [16:58:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] .. learning_rate=0.1, max_depth=2, n_estimators=10, total=   1.0s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=10 .................
# [16:58:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [CV] .. learning_rate=0.1, max_depth=2, n_estimators=10, total=   0.6s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=50 .................
# [16:58:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.1, max_depth=2, n_estimators=50, total=   1.0s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=50 .................
# [16:58:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.1, max_depth=2, n_estimators=50, total=   2.0s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=100 ................
# [16:58:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.1, max_depth=2, n_estimators=100, total=   2.0s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=100 ................
# [16:58:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.1, max_depth=2, n_estimators=100, total=   3.9s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=150 ................
# [16:58:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.1, max_depth=2, n_estimators=150, total=   3.0s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=150 ................
# [16:58:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.1, max_depth=2, n_estimators=150, total=   5.8s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=10 .................
# [16:59:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.1, max_depth=5, n_estimators=10, total=   0.5s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=10 .................
# [16:59:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.1, max_depth=5, n_estimators=10, total=   1.0s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=50 .................
# [16:59:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.1, max_depth=5, n_estimators=50, total=   2.4s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=50 .................
# [16:59:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.1, max_depth=5, n_estimators=50, total=   4.5s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=100 ................
# [16:59:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.1, max_depth=5, n_estimators=100, total=   4.9s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=100 ................
# [16:59:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.1, max_depth=5, n_estimators=100, total=   9.4s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=150 ................
# [16:59:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.1, max_depth=5, n_estimators=150, total=   7.7s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=150 ................
# [16:59:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.1, max_depth=5, n_estimators=150, total=  14.4s
# [CV] learning_rate=0.1, max_depth=12, n_estimators=10 ................
# [16:59:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.1, max_depth=12, n_estimators=10, total=   1.1s
# [CV] learning_rate=0.1, max_depth=12, n_estimators=10 ................
# [16:59:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.1, max_depth=12, n_estimators=10, total=   2.2s
# [CV] learning_rate=0.1, max_depth=12, n_estimators=50 ................
# [16:59:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.1, max_depth=12, n_estimators=50, total=   6.4s
# [CV] learning_rate=0.1, max_depth=12, n_estimators=50 ................
# [17:00:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.1, max_depth=12, n_estimators=50, total=  13.3s
# [CV] learning_rate=0.1, max_depth=12, n_estimators=100 ...............
# [17:00:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.1, max_depth=12, n_estimators=100, total=  17.0s
# [CV] learning_rate=0.1, max_depth=12, n_estimators=100 ...............
# [17:00:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.1, max_depth=12, n_estimators=100, total=  34.6s
# [CV] learning_rate=0.1, max_depth=12, n_estimators=150 ...............
# [17:01:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.1, max_depth=12, n_estimators=150, total=  27.7s
# [CV] learning_rate=0.1, max_depth=12, n_estimators=150 ...............
# [17:01:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.1, max_depth=12, n_estimators=150, total=  56.7s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=10 ................
# [17:02:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.01, max_depth=2, n_estimators=10, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=10 ................
# [17:02:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.01, max_depth=2, n_estimators=10, total=   0.6s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=50 ................
# [17:02:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.01, max_depth=2, n_estimators=50, total=   1.1s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=50 ................
# [17:02:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.01, max_depth=2, n_estimators=50, total=   2.1s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=100 ...............
# [17:02:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=100, total=   2.0s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=100 ...............
# [17:02:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=100, total=   4.0s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=150 ...............
# [17:02:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=150, total=   2.9s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=150 ...............
# [17:02:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=150, total=   6.0s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=10 ................
# [17:02:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.01, max_depth=5, n_estimators=10, total=   0.5s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=10 ................
# [17:02:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.01, max_depth=5, n_estimators=10, total=   1.1s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=50 ................
# [17:02:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.01, max_depth=5, n_estimators=50, total=   2.3s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=50 ................
# [17:02:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.01, max_depth=5, n_estimators=50, total=   4.4s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=100 ...............
# [17:02:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=100, total=   4.4s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=100 ...............
# [17:03:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=100, total=   8.5s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=150 ...............
# [17:03:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=150, total=   6.5s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=150 ...............
# [17:03:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=150, total=  13.0s
# [CV] learning_rate=0.01, max_depth=12, n_estimators=10 ...............
# [17:03:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.01, max_depth=12, n_estimators=10, total=   1.1s
# [CV] learning_rate=0.01, max_depth=12, n_estimators=10 ...............
# [17:03:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.01, max_depth=12, n_estimators=10, total=   2.2s
# [CV] learning_rate=0.01, max_depth=12, n_estimators=50 ...............
# [17:03:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.01, max_depth=12, n_estimators=50, total=   5.2s
# [CV] learning_rate=0.01, max_depth=12, n_estimators=50 ...............
# [17:03:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.01, max_depth=12, n_estimators=50, total=  10.2s
# [CV] learning_rate=0.01, max_depth=12, n_estimators=100 ..............
# [17:03:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.01, max_depth=12, n_estimators=100, total=  10.4s
# [CV] learning_rate=0.01, max_depth=12, n_estimators=100 ..............
# [17:03:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.01, max_depth=12, n_estimators=100, total=  20.4s
# [CV] learning_rate=0.01, max_depth=12, n_estimators=150 ..............
# [17:04:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.01, max_depth=12, n_estimators=150, total=  15.7s
# [CV] learning_rate=0.01, max_depth=12, n_estimators=150 ..............
# [17:04:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.01, max_depth=12, n_estimators=150, total=  30.9s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=10 ................
# [17:05:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.05, max_depth=2, n_estimators=10, total=   0.3s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=10 ................
# [17:05:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.05, max_depth=2, n_estimators=10, total=   0.6s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=50 ................
# [17:05:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.05, max_depth=2, n_estimators=50, total=   1.0s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=50 ................
# [17:05:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.05, max_depth=2, n_estimators=50, total=   2.1s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=100 ...............
# [17:05:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=100, total=   2.0s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=100 ...............
# [17:05:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=100, total=   4.0s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=150 ...............
# [17:05:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=150, total=   3.0s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=150 ...............
# [17:05:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=150, total=   6.0s
# [CV] learning_rate=0.05, max_depth=5, n_estimators=10 ................
# [17:05:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.05, max_depth=5, n_estimators=10, total=   0.5s
# [CV] learning_rate=0.05, max_depth=5, n_estimators=10 ................
# [17:05:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.05, max_depth=5, n_estimators=10, total=   1.1s
# [CV] learning_rate=0.05, max_depth=5, n_estimators=50 ................
# [17:05:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.05, max_depth=5, n_estimators=50, total=   2.3s
# [CV] learning_rate=0.05, max_depth=5, n_estimators=50 ................
# [17:05:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] . learning_rate=0.05, max_depth=5, n_estimators=50, total=   4.4s
# [CV] learning_rate=0.05, max_depth=5, n_estimators=100 ...............
# [17:05:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.05, max_depth=5, n_estimators=100, total=   4.7s
# [CV] learning_rate=0.05, max_depth=5, n_estimators=100 ...............
# [17:05:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.05, max_depth=5, n_estimators=100, total=   8.7s
# [CV] learning_rate=0.05, max_depth=5, n_estimators=150 ...............
# [17:05:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.05, max_depth=5, n_estimators=150, total=   7.0s
# [CV] learning_rate=0.05, max_depth=5, n_estimators=150 ...............
# [17:05:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.05, max_depth=5, n_estimators=150, total=  13.7s
# [CV] learning_rate=0.05, max_depth=12, n_estimators=10 ...............
# [17:06:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.05, max_depth=12, n_estimators=10, total=   1.1s
# [CV] learning_rate=0.05, max_depth=12, n_estimators=10 ...............
# [17:06:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.05, max_depth=12, n_estimators=10, total=   2.2s
# [CV] learning_rate=0.05, max_depth=12, n_estimators=50 ...............
# [17:06:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.05, max_depth=12, n_estimators=50, total=   5.4s
# [CV] learning_rate=0.05, max_depth=12, n_estimators=50 ...............
# [17:06:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.05, max_depth=12, n_estimators=50, total=  10.9s
# [CV] learning_rate=0.05, max_depth=12, n_estimators=100 ..............
# [17:06:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.05, max_depth=12, n_estimators=100, total=  12.9s
# [CV] learning_rate=0.05, max_depth=12, n_estimators=100 ..............
# [17:06:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.05, max_depth=12, n_estimators=100, total=  25.5s
# [CV] learning_rate=0.05, max_depth=12, n_estimators=150 ..............
# [17:07:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.05, max_depth=12, n_estimators=150, total=  22.7s
# [CV] learning_rate=0.05, max_depth=12, n_estimators=150 ..............
# [17:07:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  learning_rate=0.05, max_depth=12, n_estimators=150, total=  46.9s
# [17:08:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Done  72 out of  72 | elapsed:  9.5min finished
# GridSearchCV(cv=TimeSeriesSplit(max_train_size=None, n_splits=2),
#              error_score=nan,
#              estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                     colsample_bylevel=1, colsample_bynode=1,
#                                     colsample_bytree=1, gamma=0,
#                                     importance_type='gain', learning_rate=0.1,
#                                     max_delta_step=0, max_depth=3,
#                                     min_child_weight=1, missing=None,
#                                     n_estimators=100, n_jobs=1, nthread=None,
#                                     objective='reg:linear', random_state=0,
#                                     reg_alpha=0, reg_lambda=1,
#                                     scale_pos_weight=1, seed=None, silent=None,
#                                     subsample=1, verbosity=1),
#              iid='deprecated', n_jobs=None,
#              param_grid={'learning_rate': [0.1, 0.01, 0.05],
#                          'max_depth': [2, 5, 12],
#                          'n_estimators': [10, 50, 100, 150]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=2)

# %%
print(CV_xgbmodel.best_score_, CV_xgbmodel.best_params_)

evaluate_model(CV_xgbmodel, X_valid, y_valid)
#The results for the values of learning rate, max_depth and n_estiators are same for both the window sizes
#The values are close to the dummy regressor values
#Best MSE window 15
# Out:
# -0.008547227883546449 {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 10}
# (50.01383215746997, 3.527062184506935)

# %%
import xgboost as xgb #### of 0.1
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import TimeSeriesSplit
xgbreg = xgb.XGBRegressor()
param_grid = {'max_depth': [2,3,4,5,6], 
              'n_estimators': [10, 20, 30, 40],
              'learning_rate': [0.1, 0.2, 0.3, 0.4]}
X_train, y_train, X_valid, y_valid = load_data(5)
y_train = y_train.values.reshape(y_train.shape[0],)
my_cv = TimeSeriesSplit(n_splits=2)
CV_xgbmodel = GridSearchCV(estimator=xgbreg, param_grid=param_grid, cv = my_cv, verbose = 2) #n_jobs = -1
CV_xgbmodel.fit(X_train, y_train)
#2nd Grid Search with parameters since we found the highest learning rate from previous grid search to work best we tried values of [0.1, 0.2, 0.3, 0.4] and the n_estimators and max_depth were on the lower side so we try low n_estimator values.
# Out:
# Fitting 2 folds for each of 80 candidates, totalling 160 fits
# [CV] learning_rate=0.1, max_depth=2, n_estimators=10 .................
# [08:20:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] .. learning_rate=0.1, max_depth=2, n_estimators=10, total=   1.1s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=10 .................
# [08:20:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s remaining:    0.0s
# [CV] .. learning_rate=0.1, max_depth=2, n_estimators=10, total=   0.8s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=20 .................
# [08:20:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.1, max_depth=2, n_estimators=20, total=   0.6s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=20 .................
# [08:20:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.1, max_depth=2, n_estimators=20, total=   1.2s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=30 .................
# [08:20:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.1, max_depth=2, n_estimators=30, total=   0.8s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=30 .................
# [08:20:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.1, max_depth=2, n_estimators=30, total=   1.7s
# [CV] learning_rate=0.1, max_depth=2, n_estimators
27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.2, max_depth=6, n_estimators=40, total=   4.5s
# [CV] learning_rate=0.3, max_depth=2, n_estimators=10 .................
# [09:01:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=2, n_estimators=10, total=   0.3s
# [CV] learning_rate=0.3, max_depth=2, n_estimators=10 .................
# [09:01:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=2, n_estimators=10, total=   0.6s
# [CV] learning_rate=0.3, max_depth=2, n_estimators=20 .................
# [09:01:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=2, n_estimators=20, total=   0.5s
# [CV] learning_rate=0.3, max_depth=2, n_estimators=20 .................
# [09:01:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=2, n_estimators=20, total=   0.9s
# [CV] learning_rate=0.3, max_depth=2, n_estimators=30 .................
# [09:01:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=2, n_estimators=30, total=   0.7s
# [CV] learning_rate=0.3, max_depth=2, n_estimators=30 .................
# [09:01:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=2, n_estimators=30, total=   1.3s
# [CV] learning_rate=0.3, max_depth=2, n_estimators=40 .................
# [09:01:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=2, n_estimators=40, total=   0.9s
# [CV] learning_rate=0.3, max_depth=2, n_estimators=40 .................
# [09:01:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=2, n_estimators=40, total=   1.7s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=10 .................
# [09:01:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=3, n_estimators=10, total=   0.4s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=10 .................
# [09:01:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=3, n_estimators=10, total=   0.7s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=20 .................
# [09:01:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=3, n_estimators=20, total=   0.6s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=20 .................
# [09:01:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=3, n_estimators=20, total=   1.2s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=30 .................
# [09:01:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=3, n_estimators=30, total=   0.9s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=30 .................
# [09:01:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=3, n_estimators=30, total=   1.8s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=40 .................
# [09:01:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=3, n_estimators=40, total=   1.3s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=40 .................
# [09:01:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=3, n_estimators=40, total=   2.4s
# [CV] learning_rate=0.3, max_depth=4, n_estimators=10 .................
# [09:01:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=4, n_estimators=10, total=   0.4s
# [CV] learning_rate=0.3, max_depth=4, n_estimators=10 .................
# [09:01:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=4, n_estimators=10, total=   0.9s
# [CV] learning_rate=0.3, max_depth=4, n_estimators=20 .................
# [09:01:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=4, n_estimators=20, total=   0.8s
# [CV] learning_rate=0.3, max_depth=4, n_estimators=20 .................
# [09:01:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=4, n_estimators=20, total=   1.6s
# [CV] learning_rate=0.3, max_depth=4, n_estimators=30 .................
# [09:01:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=4, n_estimators=30, total=   1.2s
# [CV] learning_rate=0.3, max_depth=4, n_estimators=30 .................
# [09:01:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=4, n_estimators=30, total=   2.3s
# [CV] learning_rate=0.3, max_depth=4, n_estimators=40 .................
# [09:01:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=4, n_estimators=40, total=   1.6s
# [CV] learning_rate=0.3, max_depth=4, n_estimators=40 .................
# [09:01:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=4, n_estimators=40, total=   3.1s
# [CV] learning_rate=0.3, max_depth=5, n_estimators=10 .................
# [09:02:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=5, n_estimators=10, total=   0.5s
# [CV] learning_rate=0.3, max_depth=5, n_estimators=10 .................
# [09:02:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=5, n_estimators=10, total=   1.0s
# [CV] learning_rate=0.3, max_depth=5, n_estimators=20 .................
# [09:02:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=5, n_estimators=20, total=   1.0s
# [CV] learning_rate=0.3, max_depth=5, n_estimators=20 .................
# [09:02:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=5, n_estimators=20, total=   1.9s
# [CV] learning_rate=0.3, max_depth=5, n_estimators=30 .................
# [09:02:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=5, n_estimators=30, total=   1.5s
# [CV] learning_rate=0.3, max_depth=5, n_estimators=30 .................
# [09:02:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=5, n_estimators=30, total=   2.9s
# [CV] learning_rate=0.3, max_depth=5, n_estimators=40 .................
# [09:02:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=5, n_estimators=40, total=   2.0s
# [CV] learning_rate=0.3, max_depth=5, n_estimators=40 .................
# [09:02:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=5, n_estimators=40, total=   3.9s
# [CV] learning_rate=0.3, max_depth=6, n_estimators=10 .................
# [09:02:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=6, n_estimators=10, total=   0.7s
# [CV] learning_rate=0.3, max_depth=6, n_estimators=10 .................
# [09:02:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=6, n_estimators=10, total=   1.2s
# [CV] learning_rate=0.3, max_depth=6, n_estimators=20 .................
# [09:02:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=6, n_estimators=20, total=   1.2s
# [CV] learning_rate=0.3, max_depth=6, n_estimators=20 .................
# [09:02:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=6, n_estimators=20, total=   2.3s
# [CV] learning_rate=0.3, max_depth=6, n_estimators=30 .................
# [09:02:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=6, n_estimators=30, total=   1.8s
# [CV] learning_rate=0.3, max_depth=6, n_estimators=30 .................
# [09:02:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=6, n_estimators=30, total=   3.5s
# [CV] learning_rate=0.3, max_depth=6, n_estimators=40 .................
# [09:02:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=6, n_estimators=40, total=   2.5s
# [CV] learning_rate=0.3, max_depth=6, n_estimators=40 .................
# [09:02:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.3, max_depth=6, n_estimators=40, total=   4.7s
# [CV] learning_rate=0.4, max_depth=2, n_estimators=10 .................
# [09:02:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=2, n_estimators=10, total=   0.3s
# [CV] learning_rate=0.4, max_depth=2, n_estimators=10 .................
# [09:02:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=2, n_estimators=10, total=   0.6s
# [CV] learning_rate=0.4, max_depth=2, n_estimators=20 .................
# [09:02:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=2, n_estimators=20, total=   0.5s
# [CV] learning_rate=0.4, max_depth=2, n_estimators=20 .................
# [09:02:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=2, n_estimators=20, total=   0.9s
# [CV] learning_rate=0.4, max_depth=2, n_estimators=30 .................
# [09:02:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=2, n_estimators=30, total=   0.7s
# [CV] learning_rate=0.4, max_depth=2, n_estimators=30 .................
# [09:02:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=2, n_estimators=30, total=   1.3s
# [CV] learning_rate=0.4, max_depth=2, n_estimators=40 .................
# [09:02:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=2, n_estimators=40, total=   0.9s
# [CV] learning_rate=0.4, max_depth=2, n_estimators=40 .................
# [09:02:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=2, n_estimators=40, total=   1.7s
# [CV] learning_rate=0.4, max_depth=3, n_estimators=10 .................
# [09:02:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=3, n_estimators=10, total=   0.4s
# [CV] learning_rate=0.4, max_depth=3, n_estimators=10 .................
# [09:02:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=3, n_estimators=10, total=   0.7s
# [CV] learning_rate=0.4, max_depth=3, n_estimators=20 .................
# [09:02:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=3, n_estimators=20, total=   0.7s
# [CV] learning_rate=0.4, max_depth=3, n_estimators=20 .................
# [09:02:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=3, n_estimators=20, total=   1.2s
# [CV] learning_rate=0.4, max_depth=3, n_estimators=30 .................
# [09:02:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=3, n_estimators=30, total=   0.9s
# [CV] learning_rate=0.4, max_depth=3, n_estimators=30 .................
# [09:02:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=3, n_estimators=30, total=   1.8s
# [CV] learning_rate=0.4, max_depth=3, n_estimators=40 .................
# [09:02:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=3, n_estimators=40, total=   1.3s
# [CV] learning_rate=0.4, max_depth=3, n_estimators=40 .................
# [09:02:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=3, n_estimators=40, total=   2.3s
# [CV] learning_rate=0.4, max_depth=4, n_estimators=10 .................
# [09:02:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=4, n_estimators=10, total=   0.5s
# [CV] learning_rate=0.4, max_depth=4, n_estimators=10 .................
# [09:02:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=4, n_estimators=10, total=   0.9s
# [CV] learning_rate=0.4, max_depth=4, n_estimators=20 .................
# [09:02:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=4, n_estimators=20, total=   0.8s
# [CV] learning_rate=0.4, max_depth=4, n_estimators=20 .................
# [09:02:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=4, n_estimators=20, total=   1.6s
# [CV] learning_rate=0.4, max_depth=4, n_estimators=30 .................
# [09:02:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=4, n_estimators=30, total=   1.2s
# [CV] learning_rate=0.4, max_depth=4, n_estimators=30 .................
# [09:02:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=4, n_estimators=30, total=   2.3s
# [CV] learning_rate=0.4, max_depth=4, n_estimators=40 .................
# [09:02:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=4, n_estimators=40, total=   1.7s
# [CV] learning_rate=0.4, max_depth=4, n_estimators=40 .................
# [09:02:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=4, n_estimators=40, total=   3.2s
# [CV] learning_rate=0.4, max_depth=5, n_estimators=10 .................
# [09:03:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=5, n_estimators=10, total=   0.6s
# [CV] learning_rate=0.4, max_depth=5, n_estimators=10 .................
# [09:03:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=5, n_estimators=10, total=   1.1s
# [CV] learning_rate=0.4, max_depth=5, n_estimators=20 .................
# [09:03:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=5, n_estimators=20, total=   1.0s
# [CV] learning_rate=0.4, max_depth=5, n_estimators=20 .................
# [09:03:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=5, n_estimators=20, total=   2.0s
# [CV] learning_rate=0.4, max_depth=5, n_estimators=30 .................
# [09:03:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=5, n_estimators=30, total=   1.6s
# [CV] learning_rate=0.4, max_depth=5, n_estimators=30 .................
# [09:03:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=5, n_estimators=30, total=   2.9s
# [CV] learning_rate=0.4, max_depth=5, n_estimators=40 .................
# [09:03:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=5, n_estimators=40, total=   2.1s
# [CV] learning_rate=0.4, max_depth=5, n_estimators=40 .................
# [09:03:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=5, n_estimators=40, total=   3.9s
# [CV] learning_rate=0.4, max_depth=6, n_estimators=10 .................
# [09:03:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=6, n_estimators=10, total=   0.6s
# [CV] learning_rate=0.4, max_depth=6, n_estimators=10 .................
# [09:03:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=6, n_estimators=10, total=   1.2s
# [CV] learning_rate=0.4, max_depth=6, n_estimators=20 .................
# [09:03:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=6, n_estimators=20, total=   1.3s
# [CV] learning_rate=0.4, max_depth=6, n_estimators=20 .................
# [09:03:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=6, n_estimators=20, total=   2.4s
# [CV] learning_rate=0.4, max_depth=6, n_estimators=30 .................
# [09:03:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=6, n_estimators=30, total=   1.9s
# [CV] learning_rate=0.4, max_depth=6, n_estimators=30 .................
# [09:03:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=6, n_estimators=30, total=   3.6s
# [CV] learning_rate=0.4, max_depth=6, n_estimators=40 .................
# [09:03:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=6, n_estimators=40, total=   2.5s
# [CV] learning_rate=0.4, max_depth=6, n_estimators=40 .................
# [09:03:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] .. learning_rate=0.4, max_depth=6, n_estimators=40, total=   4.9s
# [09:03:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Done 160 out of 160 | elapsed:  4.0min finished
# GridSearchCV(cv=TimeSeriesSplit(max_train_size=None, n_splits=2),
#              error_score=nan,
#              estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                     colsample_bylevel=1, colsample_bynode=1,
#                                     colsample_bytree=1, gamma=0,
#                                     importance_type='gain', learning_rate=0.1,
#                                     max_delta_step=0, max_depth=3,
#                                     min_child_weight=1, missing=None,
#                                     n_estimators=100, n_jobs=1, nthread=None,
#                                     objective='reg:linear', random_state=0,
#                                     reg_alpha=0, reg_lambda=1,
#                                     scale_pos_weight=1, seed=None, silent=None,
#                                     subsample=1, verbosity=1),
#              iid='deprecated', n_jobs=None,
#              param_grid={'learning_rate': [0.1, 0.2, 0.3, 0.4],
#                          'max_depth': [2, 3, 4, 5, 6],
#                          'n_estimators': [10, 20, 30, 40]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=2)

# %%
print(CV_xgbmodel.best_score_, CV_xgbmodel.best_params_) #same results as the 1st grid search for best params

evaluate_model(CV_xgbmodel, X_valid, y_valid)
#Best MAE window 15
# Out:
# -0.044547374048633404 {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 10}
# (52.6000696096425, 3.5082906674664693)

# %%
#Changing the time split in Time Series split
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import TimeSeriesSplit
xgbreg = xgb.XGBRegressor()
param_grid = {'max_depth': [2,3,4], 
              'n_estimators': [10, 20],
              'learning_rate': [0.1, 0.2, 0.3],
              }
X_train, y_train, X_valid, y_valid = load_data(5)
y_train = y_train.values.reshape(y_train.shape[0],)
my_cv = TimeSeriesSplit(n_splits=3)
CV_xgbmodel = GridSearchCV(estimator=xgbreg, param_grid=param_grid, cv = my_cv, verbose = 2, n_jobs = -1) #n_jobs = -1
CV_xgbmodel.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:   34.6s
# [Parallel(n_jobs=-1)]: Done  54 out of  54 | elapsed:   50.5s finished
# [09:04:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# GridSearchCV(cv=TimeSeriesSplit(max_train_size=None, n_splits=3),
#              error_score=nan,
#              estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                     colsample_bylevel=1, colsample_bynode=1,
#                                     colsample_bytree=1, gamma=0,
#                                     importance_type='gain', learning_rate=0.1,
#                                     max_delta_step=0, max_depth=3,
#                                     min_child_weight=1, missing=None,
#                                     n_estimators=100, n_jobs=1, nthread=None,
#                                     objective='reg:linear', random_state=0,
#                                     reg_alpha=0, reg_lambda=1,
#                                     scale_pos_weight=1, seed=None, silent=None,
#                                     subsample=1, verbosity=1),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'learning_rate': [0.1, 0.2, 0.3],
#                          'max_depth': [2, 3, 4], 'n_estimators': [10, 20]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=2)

# %%
print(CV_xgbmodel.best_score_, CV_xgbmodel.best_params_) #with a varied time split still the model is performing a bit worse and doesn't have the best outputs even the mean squared error and mean absolute error increases in the model

evaluate_model(CV_xgbmodel, X_valid, y_valid)
# Out:
# -0.013092404537533095 {'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 10}
# (26.403812970998516, 2.5873915224981574)

# %%
#Even after trying multiple combinations with different learning rates [0.01, 0.01, 0,1, 0.2, 0.3, 0,4] and max depth [2, 3, 4, 5, 6, 12] and [10,20,30,40,50,100, 150] in addition to this different time spits were also tried of 2 and 3.
#the best mae for window size 5 is 2.5 and window size 15 is 3.5 hence, there has not been much improvement with an xg boost model till now

# %%
#Final Grid Search  xgboost with low number of estimators and low max depths on window 5 as they performed best for earlier cases 
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import TimeSeriesSplit
xgbreg = xgb.XGBRegressor()
param_grid = {'max_depth': [2,3,4,5,6], 
              'n_estimators': [2,4,5,6,7,8,9],
              'learning_rate': [0.1, 0.2, 0.3, 0.4]}
X_train, y_train, X_valid, y_valid = load_data(5)
y_train = y_train.values.reshape(y_train.shape[0],)
my_cv = TimeSeriesSplit(n_splits=2)
CV_xgbmodel = GridSearchCV(estimator=xgbreg, param_grid=param_grid, cv = my_cv, verbose = 2) #n_jobs = -1
CV_xgbmodel.fit(X_train, y_train)
# Out:
# Fitting 2 folds for each of 140 candidates, totalling 280 fits
# [CV] learning_rate=0.1, max_depth=2, n_estimators=2 ..................
# [15:24:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ... learning_rate=0.1, max_depth=2, n_estimators=2, total=   0.9s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=2 ..................
# [15:24:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s remaining:    0.0s
# [CV] ... learning_rate=0.1, max_depth=2, n_estimators=2, total=   0.3s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=4 ..................
# [15:24:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=2, n_estimators=4, total=   0.2s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=4 ..................
# [15:24:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=2, n_estimators=4, total=   0.4s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=5 ..................
# [15:24:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=2, n_estimators=5, total=   0.2s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=5 ..................
# [15:24:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=2, n_estimators=5, total=   0.5s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=6 ..................
# [15:24:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=2, n_estimators=6, total=   0.2s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=6 ..................
# [15:24:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=2, n_estimators=6, total=   0.5s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=7 ..................
# [15:24:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=2, n_estimators=7, total=   0.3s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=7 ..................
# [15:24:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=2, n_estimators=7, total=   0.6s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=8 ..................
# [15:24:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=2, n_estimators=8, total=   0.3s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=8 ..................
# [15:24:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=2, n_estimators=8, total=   0.6s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=9 ..................
# [15:24:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=2, n_estimators=9, total=   0.3s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=9 ..................
# [15:24:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=2, n_estimators=9, total=   0.7s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=2 ..................
# [15:24:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=3, n_estimators=2, total=   0.2s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=2 ..................
# [15:24:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=3, n_estimators=2, total=   0.4s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=4 ..................
# [15:24:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=3, n_estimators=4, total=   0.2s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=4 ..................
# [15:24:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=3, n_estimators=4, total=   0.5s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=5 ..................
# [15:24:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=3, n_estimators=5, total=   0.3s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=5 ..................
# [15:24:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=3, n_estimators=5, total=   0.6s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=6 ..................
# [15:24:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=3, n_estimators=6, total=   0.3s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=6 ..................
# [15:24:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=3, n_estimators=6, total=   0.6s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=7 ..................
# [15:24:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=3, n_estimators=7, total=   0.3s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=7 ..................
# [15:24:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=3, n_estimators=7, total=   0.7s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=8 ..................
# [15:24:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=3, n_estimators=8, total=   0.4s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=8 ..................
# [15:24:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=3, n_estimators=8, total=   0.7s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=9 ..................
# [15:24:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=3, n_estimators=9, total=   0.4s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=9 ..................
# [15:24:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=3, n_estimators=9, total=   0.8s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=2 ..................
# [15:24:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=4, n_estimators=2, total=   0.2s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=2 ..................
# [15:24:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=4, n_estimators=2, total=   0.4s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=4 ..................
# [15:24:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=4, n_estimators=4, total=   0.3s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=4 ..................
# [15:24:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=4, n_estimators=4, total=   0.6s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=5 ..................
# [15:24:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=4, n_estimators=5, total=   0.3s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=5 ..................
# [15:24:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=4, n_estimators=5, total=   0.7s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=6 ..................
# [15:24:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=4, n_estimators=6, total=   0.4s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=6 ..................
# [15:24:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=4, n_estimators
22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=6, n_estimators=5, total=   0.6s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=5 ..................
# [15:25:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=6, n_estimators=5, total=   0.8s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=6 ..................
# [15:25:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=6, n_estimators=6, total=   0.5s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=6 ..................
# [15:25:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=6, n_estimators=6, total=   1.0s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=7 ..................
# [15:25:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=6, n_estimators=7, total=   0.6s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=7 ..................
# [15:25:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=6, n_estimators=7, total=   1.1s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=8 ..................
# [15:25:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=6, n_estimators=8, total=   0.6s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=8 ..................
# [15:25:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=6, n_estimators=8, total=   1.3s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=9 ..................
# [15:25:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=6, n_estimators=9, total=   0.7s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=9 ..................
# [15:25:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=6, n_estimators=9, total=   1.4s
# [CV] learning_rate=0.3, max_depth=2, n_estimators=2 ..................
# [15:25:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=2, n_estimators=2, total=   0.2s
# [CV] learning_rate=0.3, max_depth=2, n_estimators=2 ..................
# [15:25:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=2, n_estimators=2, total=   0.3s
# [CV] learning_rate=0.3, max_depth=2, n_estimators=4 ..................
# [15:25:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=2, n_estimators=4, total=   0.2s
# [CV] learning_rate=0.3, max_depth=2, n_estimators=4 ..................
# [15:25:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=2, n_estimators=4, total=   0.4s
# [CV] learning_rate=0.3, max_depth=2, n_estimators=5 ..................
# [15:25:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=2, n_estimators=5, total=   0.2s
# [CV] learning_rate=0.3, max_depth=2, n_estimators=5 ..................
# [15:25:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=2, n_estimators=5, total=   0.5s
# [CV] learning_rate=0.3, max_depth=2, n_estimators=6 ..................
# [15:25:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=2, n_estimators=6, total=   0.3s
# [CV] learning_rate=0.3, max_depth=2, n_estimators=6 ..................
# [15:25:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=2, n_estimators=6, total=   0.6s
# [CV] learning_rate=0.3, max_depth=2, n_estimators=7 ..................
# [15:25:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=2, n_estimators=7, total=   0.3s
# [CV] learning_rate=0.3, max_depth=2, n_estimators=7 ..................
# [15:25:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=2, n_estimators=7, total=   0.6s
# [CV] learning_rate=0.3, max_depth=2, n_estimators=8 ..................
# [15:25:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=2, n_estimators=8, total=   0.3s
# [CV] learning_rate=0.3, max_depth=2, n_estimators=8 ..................
# [15:25:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=2, n_estimators=8, total=   0.7s
# [CV] learning_rate=0.3, max_depth=2, n_estimators=9 ..................
# [15:25:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=2, n_estimators=9, total=   0.3s
# [CV] learning_rate=0.3, max_depth=2, n_estimators=9 ..................
# [15:25:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=2, n_estimators=9, total=   0.7s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=2 ..................
# [15:25:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=3, n_estimators=2, total=   0.2s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=2 ..................
# [15:25:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=3, n_estimators=2, total=   0.4s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=4 ..................
# [15:25:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=3, n_estimators=4, total=   0.2s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=4 ..................
# [15:25:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=3, n_estimators=4, total=   0.5s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=5 ..................
# [15:25:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=3, n_estimators=5, total=   0.3s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=5 ..................
# [15:25:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=3, n_estimators=5, total=   0.6s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=6 ..................
# [15:25:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=3, n_estimators=6, total=   0.3s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=6 ..................
# [15:25:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=3, n_estimators=6, total=   0.7s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=7 ..................
# [15:25:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=3, n_estimators=7, total=   0.3s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=7 ..................
# [15:25:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=3, n_estimators=7, total=   0.7s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=8 ..................
# [15:25:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=3, n_estimators=8, total=   0.4s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=8 ..................
# [15:25:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=3, n_estimators=8, total=   0.8s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=9 ..................
# [15:25:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=3, n_estimators=9, total=   0.4s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=9 ..................
# [15:25:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=3, n_estimators=9, total=   0.9s
# [CV] learning_rate=0.3, max_depth=4, n_estimators=2 ..................
# [15:25:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=4, n_estimators=2, total=   0.2s
# [CV] learning_rate=0.3, max_depth=4, n_estimators=2 ..................
# [15:25:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=4, n_estimators=2, total=   0.4s
# [CV] learning_rate=0.3, max_depth=4, n_estimators=4 ..................
# [15:25:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=4, n_estimators=4, total=   0.3s
# [CV] learning_rate=0.3, max_depth=4, n_estimators=4 ..................
# [15:25:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=4, n_estimators=4, total=   0.6s
# [CV] learning_rate=0.3, max_depth=4, n_estimators=5 ..................
# [15:25:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=4, n_estimators=5, total=   0.3s
# [CV] learning_rate=0.3, max_depth=4, n_estimators=5 ..................
# [15:25:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=4, n_estimators=5, total=   0.7s
# [CV] learning_rate=0.3, max_depth=4, n_estimators=6 ..................
# [15:25:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=4, n_estimators=6, total=   0.4s
# [CV] learning_rate=0.3, max_depth=4, n_estimators=6 ..................
# [15:25:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=4, n_estimators=6, total=   0.8s
# [CV] learning_rate=0.3, max_depth=4, n_estimators=7 ..................
# [15:25:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=4, n_estimators=7, total=   0.4s
# [CV] learning_rate=0.3, max_depth=4, n_estimators=7 ..................
# ...
# [CV] learning_rate=0.4, max_depth=3, n_estimators=4 ..................
# [15:26:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=3, n_estimators=4, total=   0.2s
# [CV] learning_rate=0.4, max_depth=3, n_estimators=4 ..................
# [15:26:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=3, n_estimators=4, total=   0.5s
# [CV] learning_rate=0.4, max_depth=3, n_estimators=5 ..................
# [15:26:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=3, n_estimators=5, total=   0.3s
# [CV] learning_rate=0.4, max_depth=3, n_estimators=5 ..................
# [15:26:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=3, n_estimators=5, total=   0.6s
# [CV] learning_rate=0.4, max_depth=3, n_estimators=6 ..................
# [15:26:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=3, n_estimators=6, total=   0.3s
# [CV] learning_rate=0.4, max_depth=3, n_estimators=6 ..................
# [15:26:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=3, n_estimators=6, total=   0.7s
# [CV] learning_rate=0.4, max_depth=3, n_estimators=7 ..................
# [15:26:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=3, n_estimators=7, total=   0.4s
# [CV] learning_rate=0.4, max_depth=3, n_estimators=7 ..................
# [15:26:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=3, n_estimators=7, total=   0.8s
# [CV] learning_rate=0.4, max_depth=3, n_estimators=8 ..................
# [15:26:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=3, n_estimators=8, total=   0.4s
# [CV] learning_rate=0.4, max_depth=3, n_estimators=8 ..................
# [15:26:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=3, n_estimators=8, total=   0.9s
# [CV] learning_rate=0.4, max_depth=3, n_estimators=9 ..................
# [15:26:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=3, n_estimators=9, total=   0.4s
# [CV] learning_rate=0.4, max_depth=3, n_estimators=9 ..................
# [15:26:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=3, n_estimators=9, total=   0.9s
# [CV] learning_rate=0.4, max_depth=4, n_estimators=2 ..................
# [15:26:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=4, n_estimators=2, total=   0.2s
# [CV] learning_rate=0.4, max_depth=4, n_estimators=2 ..................
# [15:26:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=4, n_estimators=2, total=   0.4s
# [CV] learning_rate=0.4, max_depth=4, n_estimators=4 ..................
# [15:26:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=4, n_estimators=4, total=   0.3s
# [CV] learning_rate=0.4, max_depth=4, n_estimators=4 ..................
# [15:26:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=4, n_estimators=4, total=   0.6s
# [CV] learning_rate=0.4, max_depth=4, n_estimators=5 ..................
# [15:26:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=4, n_estimators=5, total=   0.3s
# [CV] learning_rate=0.4, max_depth=4, n_estimators=5 ..................
# [15:26:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=4, n_estimators=5, total=   0.7s
# [CV] learning_rate=0.4, max_depth=4, n_estimators=6 ..................
# [15:26:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=4, n_estimators=6, total=   0.4s
# [CV] learning_rate=0.4, max_depth=4, n_estimators=6 ..................
# [15:26:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=4, n_estimators=6, total=   0.7s
# [CV] learning_rate=0.4, max_depth=4, n_estimators=7 ..................
# [15:26:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=4, n_estimators=7, total=   0.4s
# [CV] learning_rate=0.4, max_depth=4, n_estimators=7 ..................
# [15:26:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=4, n_estimators=7, total=   0.8s
# [CV] learning_rate=0.4, max_depth=4, n_estimators=8 ..................
# [15:26:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=4, n_estimators=8, total=   0.5s
# [CV] learning_rate=0.4, max_depth=4, n_estimators=8 ..................
# [15:26:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=4, n_estimators=8, total=   1.0s
# [CV] learning_rate=0.4, max_depth=4, n_estimators=9 ..................
# [15:26:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=4, n_estimators=9, total=   0.5s
# [CV] learning_rate=0.4, max_depth=4, n_estimators=9 ..................
# [15:26:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=4, n_estimators=9, total=   1.0s
# [CV] learning_rate=0.4, max_depth=5, n_estimators=2 ..................
# [15:26:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=5, n_estimators=2, total=   0.2s
# [CV] learning_rate=0.4, max_depth=5, n_estimators=2 ..................
# [15:26:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=5, n_estimators=2, total=   0.5s
# [CV] learning_rate=0.4, max_depth=5, n_estimators=4 ..................
# [15:26:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=5, n_estimators=4, total=   0.3s
# [CV] learning_rate=0.4, max_depth=5, n_estimators=4 ..................
# [15:26:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=5, n_estimators=4, total=   0.6s
# [CV] learning_rate=0.4, max_depth=5, n_estimators=5 ..................
# [15:26:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=5, n_estimators=5, total=   0.4s
# [CV] learning_rate=0.4, max_depth=5, n_estimators=5 ..................
# [15:26:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=5, n_estimators=5, total=   0.8s
# [CV] learning_rate=0.4, max_depth=5, n_estimators=6 ..................
# [15:26:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=5, n_estimators=6, total=   0.4s
# [CV] learning_rate=0.4, max_depth=5, n_estimators=6 ..................
# [15:26:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=5, n_estimators=6, total=   0.9s
# [CV] learning_rate=0.4, max_depth=5, n_estimators=7 ..................
# [15:26:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=5, n_estimators=7, total=   0.5s
# [CV] learning_rate=0.4, max_depth=5, n_estimators=7 ..................
# [15:26:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=5, n_estimators=7, total=   1.0s
# [CV] learning_rate=0.4, max_depth=5, n_estimators=8 ..................
# [15:26:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=5, n_estimators=8, total=   0.5s
# [CV] learning_rate=0.4, max_depth=5, n_estimators=8 ..................
# [15:26:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=5, n_estimators=8, total=   1.2s
# [CV] learning_rate=0.4, max_depth=5, n_estimators=9 ..................
# [15:26:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=5, n_estimators=9, total=   0.6s
# [CV] learning_rate=0.4, max_depth=5, n_estimators=9 ..................
# [15:26:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=5, n_estimators=9, total=   1.3s
# [CV] learning_rate=0.4, max_depth=6, n_estimators=2 ..................
# [15:26:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=6, n_estimators=2, total=   0.2s
# [CV] learning_rate=0.4, max_depth=6, n_estimators=2 ..................
# [15:26:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=6, n_estimators=2, total=   0.5s
# [CV] learning_rate=0.4, max_depth=6, n_estimators=4 ..................
# [15:26:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=6, n_estimators=4, total=   0.4s
# [CV] learning_rate=0.4, max_depth=6, n_estimators=4 ..................
# [15:26:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=6, n_estimators=4, total=   0.7s
# [CV] learning_rate=0.4, max_depth=6, n_estimators=5 ..................
# [15:26:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=6, n_estimators=5, total=   0.4s
# [CV] learning_rate=0.4, max_depth=6, n_estimators=5 ..................
# [15:26:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=6, n_estimators=5, total=   0.8s
# [CV] learning_rate=0.4, max_depth=6, n_estimators=6 ..................
# [15:26:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=6, n_estimators=6, total=   0.5s
# [CV] learning_rate=0.4, max_depth=6, n_estimators=6 ..................
# [15:26:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=6, n_estimators=6, total=   1.0s
# [CV] learning_rate=0.4, max_depth=6, n_estimators=7 ..................
# [15:26:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=6, n_estimators=7, total=   0.5s
# [CV] learning_rate=0.4, max_depth=6, n_estimators=7 ..................
# [15:26:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=6, n_estimators=7, total=   1.1s
# [CV] learning_rate=0.4, max_depth=6, n_estimators=8 ..................
# [15:26:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=6, n_estimators=8, total=   0.6s
# [CV] learning_rate=0.4, max_depth=6, n_estimators=8 ..................
# [15:26:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=6, n_estimators=8, total=   1.3s
# [CV] learning_rate=0.4, max_depth=6, n_estimators=9 ..................
# [15:26:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=6, n_estimators=9, total=   0.7s
# [CV] learning_rate=0.4, max_depth=6, n_estimators=9 ..................
# [15:26:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=6, n_estimators=9, total=   1.4s
# [15:26:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Done 280 out of 280 | elapsed:  2.7min finished
# GridSearchCV(cv=TimeSeriesSplit(max_train_size=None, n_splits=2),
#              error_score=nan,
#              estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                     colsample_bylevel=1, colsample_bynode=1,
#                                     colsample_bytree=1, gamma=0,
#                                     importance_type='gain', learning_rate=0.1,
#                                     max_delta_step=0, max_depth=3,
#                                     min_child_weight=1, missing=None,
#                                     n_estimators=100, n_jobs=1, nthread=None,
#                                     objective='reg:linear', random_state=0,
#                                     reg_alpha=0, reg_lambda=1,
#                                     scale_pos_weight=1, seed=None, silent=None,
#                                     subsample=1, verbosity=1),
#              iid='deprecated', n_jobs=None,
#              param_grid={'learning_rate': [0.1, 0.2, 0.3, 0.4],
#                          'max_depth': [2, 3, 4, 5, 6],
#                          'n_estimators': [2, 4, 5, 6, 7, 8, 9]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=2)

# %%
print(CV_xgbmodel.best_score_, CV_xgbmodel.best_params_) #This model has the best MSE value for the grid search we did

evaluate_model(CV_xgbmodel, X_valid, y_valid)
#Best MSE window 5
# Out:
# -0.0053682373960097785 {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 6}
# (25.693117844952575, 2.5944702403704256)

# %%
#Final Grid Search for xgboost with low number of estimators and low max depths on window 15 as well
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import TimeSeriesSplit
xgbreg = xgb.XGBRegressor()
param_grid = {'max_depth': [2,3,4,5,6], 
              'n_estimators': [2,4,5,6,7,8,9],
              'learning_rate': [0.1, 0.2, 0.3, 0.4]}
X_train, y_train, X_valid, y_valid = load_data(15)
y_train = y_train.values.reshape(y_train.shape[0],)
my_cv = TimeSeriesSplit(n_splits=2)
CV_xgbmodel = GridSearchCV(estimator=xgbreg, param_grid=param_grid, cv = my_cv, verbose = 2) #n_jobs = -1
CV_xgbmodel.fit(X_train, y_train)
# Out:
# Fitting 2 folds for each of 140 candidates, totalling 280 fits
# [CV] learning_rate=0.1, max_depth=2, n_estimators=2 ..................
# [15:34:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=2, n_estimators=2, total=   0.1s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=2 ..................
# [15:34:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [CV] ... learning_rate=0.1, max_depth=2, n_estimators=2, total=   0.3s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=4 ..................
# [15:34:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=2, n_estimators=4, total=   0.2s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=4 ..................
# [15:34:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=2, n_estimators=4, total=   0.3s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=5 ..................
# [15:34:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=2, n_estimators=5, total=   0.2s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=5 ..................
# [15:34:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=2, n_estimators=5, total=   0.3s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=6 ..................
# [15:34:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=2, n_estimators=6, total=   0.2s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=6 ..................
# [15:34:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=2, n_estimators=6, total=   0.4s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=7 ..................
# [15:34:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=2, n_estimators=7, total=   0.2s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=7 ..................
# [15:34:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=2, n_estimators=7, total=   0.4s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=8 ..................
# [15:34:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=2, n_estimators=8, total=   0.2s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=8 ..................
# [15:34:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=2, n_estimators=8, total=   0.4s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=9 ..................
# [15:34:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=2, n_estimators=9, total=   0.2s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=9 ..................
# [15:34:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=2, n_estimators=9, total=   0.5s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=2 ..................
# [15:34:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=3, n_estimators=2, total=   0.1s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=2 ..................
# [15:34:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=3, n_estimators=2, total=   0.3s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=4 ..................
# [15:34:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=3, n_estimators=4, total=   0.2s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=4 ..................
# [15:34:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=3, n_estimators=4, total=   0.4s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=5 ..................
# [15:34:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=3, n_estimators=5, total=   0.2s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=5 ..................
# [15:34:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=3, n_estimators=5, total=   0.4s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=6 ..................
# [15:34:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=3, n_estimators=6, total=   0.3s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=6 ..................
# [15:34:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=3, n_estimators=6, total=   0.4s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=7 ..................
# [15:34:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=3, n_estimators=7, total=   0.3s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=7 ..................
# [15:34:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=3, n_estimators=7, total=   0.5s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=8 ..................
# [15:34:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=3, n_estimators=8, total=   0.3s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=8 ..................
# [15:34:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=3, n_estimators=8, total=   0.6s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=9 ..................
# [15:34:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=3, n_estimators=9, total=   0.3s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=9 ..................
# [15:34:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=3, n_estimators=9, total=   0.6s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=2 ..................
# [15:34:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=4, n_estimators=2, total=   0.2s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=2 ..................
# [15:34:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=4, n_estimators=2, total=   0.3s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=4 ..................
# [15:34:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=4, n_estimators=4, total=   0.2s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=4 ..................
# [15:34:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=4, n_estimators=4, total=   0.4s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=5 ..................
# [15:34:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=4, n_estimators=5, total=   0.3s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=5 ..................
# [15:34:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=4, n_estimators=5, total=   0.5s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=6 ..................
# [15:34:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=4, n_estimators=6, total=   0.3s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=6 ..................
# [15:34:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=4, n_estimators=6, total=   0.5s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=7 ..................
# [15:34:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=4, n_estimators=7, total=   0.3s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=7 ..................
# [15:34:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=4, n_estimators=7, total=   0.6s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=8 ..................
# [15:34:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=4, n_estimators=8, total=   0.3s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=8 ..................
# [15:34:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=4, n_estimators=8, total=   0.7s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=9 ..................
# [15:34:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=4, n_estimators=9, total=   0.4s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=9 ..................
# [15:34:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=4, n_estimators=9, total=   0.7s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=2 ..................
# [15:34:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=5, n_estimators=2, total=   0.2s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=2 ..................
# [15:34:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=5, n_estimators=2, total=   0.3s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=4 ..................
# [15:34:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=5, n_estimators=4, total=   0.3s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=4 ..................
# [15:34:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=5, n_estimators=4, total=   0.5s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=5 ..................
# [15:34:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=5, n_estimators=5, total=   0.3s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=5 ..................
# [15:34:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=5, n_estimators=5, total=   0.5s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=6 ..................
# [15:34:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=5, n_estimators=6, total=   0.3s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=6 ..................
# [15:34:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=5, n_estimators=6, total=   0.6s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=7 ..................
# [15:34:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=5, n_estimators=7, total=   0.4s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=7 ..................
# [15:34:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=5, n_estimators=7, total=   0.7s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=8 ..................
# [15:34:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=5, n_estimators=8, total=   0.4s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=8 ..................
# [15:34:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=5, n_estimators=8, total=   0.8s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=9 ..................
# [15:34:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=5, n_estimators=9, total=   0.4s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=9 ..................
# [15:34:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=5, n_estimators=9, total=   0.9s
# [CV] learning_rate=0.1, max_depth=6, n_estimators=2 ..................
# [15:34:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=6, n_estimators=2, total=   0.2s
# [CV] learning_rate=0.1, max_depth=6, n_estimators=2 ..................
# [15:34:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=6, n_estimators=2, total=   0.4s
# [CV] learning_rate=0.1, max_depth=6, n_estimators=4 ..................
# [15:34:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=6, n_estimators=4, total=   0.3s
# [CV] learning_rate=0.1, max_depth=6, n_estimators=4 ..................
# [15:34:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=6, n_estimators=4, total=   0.5s
# [CV] learning_rate=0.1, max_depth=6, n_estimators=5 ..................
# [15:34:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=6, n_estimators=5, total=   0.3s
# [CV] learning_rate=0.1, max_depth=6, n_estimators=5 ..................
# [15:34:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=6, n_estimators=5, total=   0.6s
# [CV] learning_rate=0.1, max_depth=6, n_estimators=6 ..................
# [15:34:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=6, n_estimators=6, total=   0.4s
# [CV] learning_rate=0.1, max_depth=6, n_estimators=6 ..................
# [15:34:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=6, n_estimators=6, total=   0.7s
# [CV] learning_rate=0.1, max_depth=6, n_estimators=7 ..................
# [15:34:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=6, n_estimators=7, total=   0.4s
# [CV] learning_rate=0.1, max_depth=6, n_estimators=7 ..................
# [15:34:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=6, n_estimators=7, total=   0.8s
# [CV] learning_rate=0.1, max_depth=6, n_estimators=8 ..................
# [15:34:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=6, n_estimators=8, total=   0.5s
# [CV] learning_rate=0.1, max_depth=6, n_estimators=8 ..................
# [15:34:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=6, n_estimators=8, total=   0.9s
# [CV] learning_rate=0.1, max_depth=6, n_estimators=9 ..................
# [15:34:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=6, n_estimators=9, total=   0.5s
# [CV] learning_rate=0.1, max_depth=6, n_estimators=9 ..................
# [15:34:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.1, max_depth=6, n_estimators=9, total=   1.0s
# [CV] learning_rate=0.2, max_depth=2, n_estimators=2 ..................
# [15:34:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=2, n_estimators=2, total=   0.1s
# [CV] learning_rate=0.2, max_depth=2, n_estimators=2 ..................
# [15:34:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=2, n_estimators=2, total=   0.2s
# [CV] learning_rate=0.2, max_depth=2, n_estimators=4 ..................
# [15:34:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=2, n_estimators=4, total=   0.2s
# [CV] learning_rate=0.2, max_depth=2, n_estimators=4 ..................
# [15:34:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=2, n_estimators=4, total=   0.3s
# [CV] learning_rate=0.2, max_depth=2, n_estimators=5 ..................
# [15:34:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=2, n_estimators=5, total=   0.2s
# [CV] learning_rate=0.2, max_depth=2, n_estimators=5 ..................
# [15:34:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=2, n_estimators=5, total=   0.3s
# [CV] learning_rate=0.2, max_depth=2, n_estimators=6 ..................
# [15:34:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=2, n_estimators=6, total=   0.2s
# [CV] learning_rate=0.2, max_depth=2, n_estimators=6 ..................
# [15:34:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=2, n_estimators=6, total=   0.4s
# [CV] learning_rate=0.2, max_depth=2, n_estimators=7 ..................
# [15:34:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=2, n_estimators=7, total=   0.2s
# [CV] learning_rate=0.2, max_depth=2, n_estimators=7 ..................
# [15:34:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=2, n_estimators=7, total=   0.4s
# [CV] learning_rate=0.2, max_depth=2, n_estimators=8 ..................
# [15:34:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=2, n_estimators=8, total=   0.2s
# [CV] learning_rate=0.2, max_depth=2, n_estimators=8 ..................
# [15:34:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=2, n_estimators=8, total=   0.4s
# [CV] learning_rate=0.2, max_depth=2, n_estimators=9 ..................
# [15:34:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=2, n_estimators=9, total=   0.2s
# [CV] learning_rate=0.2, max_depth=2, n_estimators=9 ..................
# [15:34:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=2, n_estimators=9, total=   0.5s
# [CV] learning_rate=0.2, max_depth=3, n_estimators=2 ..................
# [15:34:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=3, n_estimators=2, total=   0.1s
# [CV] learning_rate=0.2, max_depth=3, n_estimators=2 ..................
# [15:34:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=3, n_estimators=2, total=   0.3s
# [CV] learning_rate=0.2, max_depth=3, n_estimators=4 ..................
# [15:34:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=3, n_estimators=4, total=   0.2s
# [CV] learning_rate=0.2, max_depth=3, n_estimators=4 ..................
# [15:34:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=3, n_estimators=4, total=   0.4s
# [CV] learning_rate=0.2, max_depth=3, n_estimators=5 ..................
# [15:34:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=3, n_estimators=5, total=   0.2s
# [CV] learning_rate=0.2, max_depth=3, n_estimators=5 ..................
# [15:34:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=3, n_estimators=5, total=   0.4s
# [CV] learning_rate=0.2, max_depth=3, n_estimators=6 ..................
# [15:34:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=3, n_estimators=6, total=   0.2s
# [CV] learning_rate=0.2, max_depth=3, n_estimators=6 ..................
# [15:35:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=3, n_estimators=6, total=   0.5s
# [CV] learning_rate=0.2, max_depth=3, n_estimators=7 ..................
# [15:35:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=3, n_estimators=7, total=   0.3s
# [CV] learning_rate=0.2, max_depth=3, n_estimators=7 ..................
# [15:35:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=3, n_estimators=7, total=   0.5s
# [CV] learning_rate=0.2, max_depth=3, n_estimators=8 ..................
# [15:35:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=3, n_estimators=8, total=   0.3s
# [CV] learning_rate=0.2, max_depth=3, n_estimators=8 ..................
# [15:35:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=3, n_estimators=8, total=   0.6s
# [CV] learning_rate=0.2, max_depth=3, n_estimators=9 ..................
# [15:35:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=3, n_estimators=9, total=   0.3s
# [CV] learning_rate=0.2, max_depth=3, n_estimators=9 ..................
# [15:35:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=3, n_estimators=9, total=   0.6s
# [CV] learning_rate=0.2, max_depth=4, n_estimators=2 ..................
# [15:35:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=4, n_estimators=2, total=   0.1s
# [CV] learning_rate=0.2, max_depth=4, n_estimators=2 ..................
# [15:35:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=4, n_estimators=2, total=   0.3s
# [CV] learning_rate=0.2, max_depth=4, n_estimators=4 ..................
# [15:35:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=4, n_estimators=4, total=   0.2s
# [CV] learning_rate=0.2, max_depth=4, n_estimators=4 ..................
# [15:35:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=4, n_estimators=4, total=   0.4s
# [CV] learning_rate=0.2, max_depth=4, n_estimators=5 ..................
# [15:35:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=4, n_estimators=5, total=   0.2s
# [CV] learning_rate=0.2, max_depth=4, n_estimators=5 ..................
# [15:35:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=4, n_estimators=5, total=   0.5s
# [CV] learning_rate=0.2, max_depth=4, n_estimators=6 ..................
# [15:35:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=4, n_estimators=6, total=   0.3s
# [CV] learning_rate=0.2, max_depth=4, n_estimators=6 ..................
# [15:35:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=4, n_estimators=6, total=   0.6s
# [CV] learning_rate=0.2, max_depth=4, n_estimators=7 ..................
# [15:35:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=4, n_estimators=7, total=   0.3s
# [CV] learning_rate=0.2, max_depth=4, n_estimators=7 ..................
# [15:35:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=4, n_estimators=7, total=   0.6s
# [CV] learning_rate=0.2, max_depth=4, n_estimators=8 ..................
# [15:35:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=4, n_estimators=8, total=   0.4s
# [CV] learning_rate=0.2, max_depth=4, n_estimators=8 ..................
# [15:35:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=4, n_estimators=8, total=   0.7s
# [CV] learning_rate=0.2, max_depth=4, n_estimators=9 ..................
# [15:35:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=4, n_estimators=9, total=   0.4s
# [CV] learning_rate=0.2, max_depth=4, n_estimators=9 ..................
# [15:35:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=4, n_estimators=9, total=   0.8s
# [CV] learning_rate=0.2, max_depth=5, n_estimators=2 ..................
# [15:35:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=5, n_estimators=2, total=   0.2s
# [CV] learning_rate=0.2, max_depth=5, n_estimators=2 ..................
# [15:35:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=5, n_estimators=2, total=   0.3s
# [CV] learning_rate=0.2, max_depth=5, n_estimators=4 ..................
# [15:35:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=5, n_estimators=4, total=   0.3s
# [CV] learning_rate=0.2, max_depth=5, n_estimators=4 ..................
# [15:35:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=5, n_estimators=4, total=   0.5s
# [CV] learning_rate=0.2, max_depth=5, n_estimators=5 ..................
# [15:35:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=5, n_estimators=5, total=   0.3s
# [CV] learning_rate=0.2, max_depth=5, n_estimators=5 ..................
# [15:35:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=5, n_estimators=5, total=   0.6s
# [CV] learning_rate=0.2, max_depth=5, n_estimators=6 ..................
# [15:35:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=5, n_estimators=6, total=   0.3s
# [CV] learning_rate=0.2, max_depth=5, n_estimators=6 ..................
# [15:35:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=5, n_estimators=6, total=   0.6s
# [CV] learning_rate=0.2, max_depth=5, n_estimators=7 ..................
# [15:35:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=5, n_estimators=7, total=   0.4s
# [CV] learning_rate=0.2, max_depth=5, n_estimators=7 ..................
# [15:35:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=5, n_estimators=7, total=   0.7s
# [CV] learning_rate=0.2, max_depth=5, n_estimators=8 ..................
# [15:35:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=5, n_estimators=8, total=   0.4s
# [CV] learning_rate=0.2, max_depth=5, n_estimators=8 ..................
# [15:35:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=5, n_estimators=8, total=   0.8s
# [CV] learning_rate=0.2, max_depth=5, n_estimators=9 ..................
# [15:35:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=5, n_estimators=9, total=   0.5s
# [CV] learning_rate=0.2, max_depth=5, n_estimators=9 ..................
# [15:35:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=5, n_estimators=9, total=   0.9s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=2 ..................
# [15:35:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=6, n_estimators=2, total=   0.2s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=2 ..................
# [15:35:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=6, n_estimators=2, total=   0.4s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=4 ..................
# [15:35:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=6, n_estimators=4, total=   0.3s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=4 ..................
# [15:35:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=6, n_estimators=4, total=   0.5s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=5 ..................
# [15:35:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=6, n_estimators=5, total=   0.3s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=5 ..................
# [15:35:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=6, n_estimators=5, total=   0.6s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=6 ..................
# [15:35:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=6, n_estimators=6, total=   0.4s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=6 ..................
# [15:35:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=6, n_estimators=6, total=   0.7s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=7 ..................
# [15:35:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=6, n_estimators=7, total=   0.4s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=7 ..................
# [15:35:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=6, n_estimators=7, total=   0.8s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=8 ..................
# [15:35:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=6, n_estimators=8, total=   0.5s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=8 ..................
# [15:35:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=6, n_estimators=8, total=   0.9s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=9 ..................
# [15:35:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=6, n_estimators=9, total=   0.5s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=9 ..................
# [15:35:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.2, max_depth=6, n_estimators=9, total=   1.0s
# [CV] learning_rate=0.3, max_depth=2, n_estimators=2 ..................
# [15:35:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=2, n_estimators=2, total=   0.1s
# [CV] learning_rate=0.3, max_depth=2, n_estimators=2 ..................
# [15:35:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=2, n_estimators=2, total=   0.2s
# [CV] learning_rate=0.3, max_depth=2, n_estimators=4 ..................
# [15:35:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=2, n_estimators=4, total=   0.2s
# [CV] learning_rate=0.3, max_depth=2, n_estimators=4 ..................
# [15:35:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=2, n_estimators=4, total=   0.3s
# [CV] learning_rate=0.3, max_depth=2, n_estimators=5 ..................
# [15:35:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=2, n_estimators=5, total=   0.2s
# [CV] learning_rate=0.3, max_depth=2, n_estimators=5 ..................
# [15:35:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=2, n_estimators=5, total=   0.4s
# [CV] learning_rate=0.3, max_depth=2, n_estimators=6 ..................
# [15:35:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=2, n_estimators=6, total=   0.2s
# [CV] learning_rate=0.3, max_depth=2, n_estimators=6 ..................
# [15:35:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=2, n_estimators=6, total=   0.4s
# [CV] learning_rate=0.3, max_depth=2, n_estimators=7 ..................
# [15:35:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=2, n_estimators=7, total=   0.2s
# [CV] learning_rate=0.3, max_depth=2, n_estimators=7 ..................
# [15:35:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=2, n_estimators=7, total=   0.4s
# [CV] learning_rate=0.3, max_depth=2, n_estimators=8 ..................
# [15:35:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=2, n_estimators=8, total=   0.2s
# [CV] learning_rate=0.3, max_depth=2, n_estimators=8 ..................
# [15:35:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=2, n_estimators=8, total=   0.4s
# [CV] learning_rate=0.3, max_depth=2, n_estimators=9 ..................
# [15:35:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=2, n_estimators=9, total=   0.3s
# [CV] learning_rate=0.3, max_depth=2, n_estimators=9 ..................
# [15:35:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=2, n_estimators=9, total=   0.5s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=2 ..................
# [15:35:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=3, n_estimators=2, total=   0.1s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=2 ..................
# [15:35:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=3, n_estimators=2, total=   0.3s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=4 ..................
# [15:35:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=3, n_estimators=4, total=   0.2s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=4 ..................
# [15:35:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=3, n_estimators=4, total=   0.4s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=5 ..................
# [15:35:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=3, n_estimators=5, total=   0.2s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=5 ..................
# [15:35:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=3, n_estimators=5, total=   0.4s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=6 ..................
# [15:35:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=3, n_estimators=6, total=   0.2s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=6 ..................
# [15:35:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=3, n_estimators=6, total=   0.5s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=7 ..................
# [15:35:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=3, n_estimators=7, total=   0.3s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=7 ..................
# [15:35:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=3, n_estimators=7, total=   0.5s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=8 ..................
# [15:35:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=3, n_estimators=8, total=   0.3s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=8 ..................
# [15:35:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=3, n_estimators=8, total=   0.6s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=9 ..................
# [15:35:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=3, n_estimators=9, total=   0.3s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=9 ..................
# [15:35:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=3, n_estimators=9, total=   0.6s
# [CV] learning_rate=0.3, max_depth=4, n_estimators=2 ..................
# [15:35:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=4, n_estimators=2, total=   0.2s
# [CV] learning_rate=0.3, max_depth=4, n_estimators=2 ..................
# [15:35:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=4, n_estimators=2, total=   0.3s
# [CV] learning_rate=0.3, max_depth=4, n_estimators=4 ..................
# [15:35:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=4, n_estimators=4, total=   0.2s
# [CV] learning_rate=0.3, max_depth=4, n_estimators=4 ..................
# [15:35:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=4, n_estimators=4, total=   0.4s
# [CV] learning_rate=0.3, max_depth=4, n_estimators=5 ..................
# [15:35:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=4, n_estimators=5, total=   0.3s
# [CV] learning_rate=0.3, max_depth=4, n_estimators=5 ..................
# [15:35:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=4, n_estimators=5, total=   0.5s
# [CV] learning_rate=0.3, max_depth=4, n_estimators=6 ..................
# [15:35:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=4, n_estimators=6, total=   0.3s
# [CV] learning_rate=0.3, max_depth=4, n_estimators=6 ..................
# [15:35:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=4, n_estimators=6, total=   0.6s
# [CV] learning_rate=0.3, max_depth=4, n_estimators=7 ..................
# [15:35:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.3, max_depth=4, n_estimators=7, total=   0.3s
# [CV] learning_rate=0.3, max_depth=4, n_estimators=7 ..................
# ...
# [CV] learning_rate=0.4, max_depth=3, n_estimators=4 ..................
# [15:35:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=3, n_estimators=4, total=   0.2s
# [CV] learning_rate=0.4, max_depth=3, n_estimators=4 ..................
# [15:35:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=3, n_estimators=4, total=   0.4s
# [CV] learning_rate=0.4, max_depth=3, n_estimators=5 ..................
# [15:35:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=3, n_estimators=5, total=   0.2s
# [CV] learning_rate=0.4, max_depth=3, n_estimators=5 ..................
# [15:35:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=3, n_estimators=5, total=   0.4s
# [CV] learning_rate=0.4, max_depth=3, n_estimators=6 ..................
# [15:35:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=3, n_estimators=6, total=   0.2s
# [CV] learning_rate=0.4, max_depth=3, n_estimators=6 ..................
# [15:35:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=3, n_estimators=6, total=   0.5s
# [CV] learning_rate=0.4, max_depth=3, n_estimators=7 ..................
# [15:35:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=3, n_estimators=7, total=   0.3s
# [CV] learning_rate=0.4, max_depth=3, n_estimators=7 ..................
# [15:35:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=3, n_estimators=7, total=   0.5s
# [CV] learning_rate=0.4, max_depth=3, n_estimators=8 ..................
# [15:35:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=3, n_estimators=8, total=   0.3s
# [CV] learning_rate=0.4, max_depth=3, n_estimators=8 ..................
# [15:35:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=3, n_estimators=8, total=   0.5s
# [CV] learning_rate=0.4, max_depth=3, n_estimators=9 ..................
# [15:36:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=3, n_estimators=9, total=   0.3s
# [CV] learning_rate=0.4, max_depth=3, n_estimators=9 ..................
# [15:36:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=3, n_estimators=9, total=   0.6s
# [CV] learning_rate=0.4, max_depth=4, n_estimators=2 ..................
# [15:36:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=4, n_estimators=2, total=   0.2s
# [CV] learning_rate=0.4, max_depth=4, n_estimators=2 ..................
# [15:36:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=4, n_estimators=2, total=   0.3s
# [CV] learning_rate=0.4, max_depth=4, n_estimators=4 ..................
# [15:36:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=4, n_estimators=4, total=   0.2s
# [CV] learning_rate=0.4, max_depth=4, n_estimators=4 ..................
# [15:36:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=4, n_estimators=4, total=   0.4s
# [CV] learning_rate=0.4, max_depth=4, n_estimators=5 ..................
# [15:36:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=4, n_estimators=5, total=   0.3s
# [CV] learning_rate=0.4, max_depth=4, n_estimators=5 ..................
# [15:36:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=4, n_estimators=5, total=   0.5s
# [CV] learning_rate=0.4, max_depth=4, n_estimators=6 ..................
# [15:36:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=4, n_estimators=6, total=   0.3s
# [CV] learning_rate=0.4, max_depth=4, n_estimators=6 ..................
# [15:36:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=4, n_estimators=6, total=   0.6s
# [CV] learning_rate=0.4, max_depth=4, n_estimators=7 ..................
# [15:36:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=4, n_estimators=7, total=   0.3s
# [CV] learning_rate=0.4, max_depth=4, n_estimators=7 ..................
# [15:36:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=4, n_estimators=7, total=   0.6s
# [CV] learning_rate=0.4, max_depth=4, n_estimators=8 ..................
# [15:36:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=4, n_estimators=8, total=   0.4s
# [CV] learning_rate=0.4, max_depth=4, n_estimators=8 ..................
# [15:36:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=4, n_estimators=8, total=   0.7s
# [CV] learning_rate=0.4, max_depth=4, n_estimators=9 ..................
# [15:36:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=4, n_estimators=9, total=   0.4s
# [CV] learning_rate=0.4, max_depth=4, n_estimators=9 ..................
# [15:36:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=4, n_estimators=9, total=   0.8s
# [CV] learning_rate=0.4, max_depth=5, n_estimators=2 ..................
# [15:36:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=5, n_estimators=2, total=   0.2s
# [CV] learning_rate=0.4, max_depth=5, n_estimators=2 ..................
# [15:36:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=5, n_estimators=2, total=   0.4s
# [CV] learning_rate=0.4, max_depth=5, n_estimators=4 ..................
# [15:36:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=5, n_estimators=4, total=   0.3s
# [CV] learning_rate=0.4, max_depth=5, n_estimators=4 ..................
# [15:36:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=5, n_estimators=4, total=   0.5s
# [CV] learning_rate=0.4, max_depth=5, n_estimators=5 ..................
# [15:36:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=5, n_estimators=5, total=   0.3s
# [CV] learning_rate=0.4, max_depth=5, n_estimators=5 ..................
# [15:36:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=5, n_estimators=5, total=   0.6s
# [CV] learning_rate=0.4, max_depth=5, n_estimators=6 ..................
# [15:36:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=5, n_estimators=6, total=   0.4s
# [CV] learning_rate=0.4, max_depth=5, n_estimators=6 ..................
# [15:36:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=5, n_estimators=6, total=   0.6s
# [CV] learning_rate=0.4, max_depth=5, n_estimators=7 ..................
# [15:36:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=5, n_estimators=7, total=   0.4s
# [CV] learning_rate=0.4, max_depth=5, n_estimators=7 ..................
# [15:36:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=5, n_estimators=7, total=   0.7s
# [CV] learning_rate=0.4, max_depth=5, n_estimators=8 ..................
# [15:36:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=5, n_estimators=8, total=   0.4s
# [CV] learning_rate=0.4, max_depth=5, n_estimators=8 ..................
# [15:36:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=5, n_estimators=8, total=   0.8s
# [CV] learning_rate=0.4, max_depth=5, n_estimators=9 ..................
# [15:36:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=5, n_estimators=9, total=   0.5s
# [CV] learning_rate=0.4, max_depth=5, n_estimators=9 ..................
# [15:36:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=5, n_estimators=9, total=   0.9s
# [CV] learning_rate=0.4, max_depth=6, n_estimators=2 ..................
# [15:36:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=6, n_estimators=2, total=   0.2s
# [CV] learning_rate=0.4, max_depth=6, n_estimators=2 ..................
# [15:36:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=6, n_estimators=2, total=   0.4s
# [CV] learning_rate=0.4, max_depth=6, n_estimators=4 ..................
# [15:36:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=6, n_estimators=4, total=   0.3s
# [CV] learning_rate=0.4, max_depth=6, n_estimators=4 ..................
# [15:36:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=6, n_estimators=4, total=   0.5s
# [CV] learning_rate=0.4, max_depth=6, n_estimators=5 ..................
# [15:36:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=6, n_estimators=5, total=   0.3s
# [CV] learning_rate=0.4, max_depth=6, n_estimators=5 ..................
# [15:36:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=6, n_estimators=5, total=   0.6s
# [CV] learning_rate=0.4, max_depth=6, n_estimators=6 ..................
# [15:36:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=6, n_estimators=6, total=   0.4s
# [CV] learning_rate=0.4, max_depth=6, n_estimators=6 ..................
# [15:36:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=6, n_estimators=6, total=   0.7s
# [CV] learning_rate=0.4, max_depth=6, n_estimators=7 ..................
# [15:36:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=6, n_estimators=7, total=   0.4s
# [CV] learning_rate=0.4, max_depth=6, n_estimators=7 ..................
# [15:36:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=6, n_estimators=7, total=   0.8s
# [CV] learning_rate=0.4, max_depth=6, n_estimators=8 ..................
# [15:36:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=6, n_estimators=8, total=   0.5s
# [CV] learning_rate=0.4, max_depth=6, n_estimators=8 ..................
# [15:36:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=6, n_estimators=8, total=   0.9s
# [CV] learning_rate=0.4, max_depth=6, n_estimators=9 ..................
# [15:36:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=6, n_estimators=9, total=   0.5s
# [CV] learning_rate=0.4, max_depth=6, n_estimators=9 ..................
# [15:36:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] ... learning_rate=0.4, max_depth=6, n_estimators=9, total=   1.0s
# [15:36:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Done 280 out of 280 | elapsed:  1.9min finished
# GridSearchCV(cv=TimeSeriesSplit(max_train_size=None, n_splits=2),
#              error_score=nan,
#              estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                     colsample_bylevel=1, colsample_bynode=1,
#                                     colsample_bytree=1, gamma=0,
#                                     importance_type='gain', learning_rate=0.1,
#                                     max_delta_step=0, max_depth=3,
#                                     min_child_weight=1, missing=None,
#                                     n_estimators=100, n_jobs=1, nthread=None,
#                                     objective='reg:linear', random_state=0,
#                                     reg_alpha=0, reg_lambda=1,
#                                     scale_pos_weight=1, seed=None, silent=None,
#                                     subsample=1, verbosity=1),
#              iid='deprecated', n_jobs=None,
#              param_grid={'learning_rate': [0.1, 0.2, 0.3, 0.4],
#                          'max_depth': [2, 3, 4, 5, 6],
#                          'n_estimators': [2, 4, 5, 6, 7, 8, 9]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=2)

# %%
print(CV_xgbmodel.best_score_, CV_xgbmodel.best_params_) 

evaluate_model(CV_xgbmodel, X_valid, y_valid)
# Out:
# -0.007342293850444492 {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 2}
# (50.430546946291095, 3.523351474567169)

# %%
#There's a certain trend in XG boost the best performing models have low number of max depth and low number of n_estimators and time split is also at its minimum
